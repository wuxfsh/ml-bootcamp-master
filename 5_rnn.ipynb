# %% [markdown]
# # Recurrent Neural Network (RNN)
# In the following we will implement and train an RNN for text classification. The following example will use the ATIS database. The ATIS database consists of data obtained from the Official Airline Guide (OAG, 1990), organized under a relational schema. The database remained fixed throughout the pilot phase. It contains information about flights, fares, airlines, cities, airports, and ground services, and includes twenty-five supporting tables. The large majority of the questions posed by subjects can be answered from the database with a single relational query.
#
# For more information about RNN check out the following resources:
#
# [RNN with Theano](http://deeplearning.net/tutorial/rnnslu.html)
#
# [Nice blog about RNN](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# [Amazing Stanford lecture about NLP (natural language processing)][http://cs224d.stanford.edu/]
#
# For advanced text processing:
#
# [Long-Short-Term-Memory (LSTM) a RNN variant](http://deeplearning.net/tutorial/lstm.html)

# %%
import theano, numpy
from theano import tensor as T
import os
import pickle
import copy
import sys
import gzip
import urllib
import random
import stat
import subprocess
import sys
import timeit
from sklearn.neighbors import NearestNeighbors
import numpy as np
from collections import OrderedDict
from sklearn.neighbors import NearestNeighbors
import numpy as np
sys.setrecursionlimit(1500)

# get home directory
from os.path import expanduser
PREFIX = expanduser("~")

# %% [markdown]
# ## Helper functions

# %%
def download(origin, destination):
    '''
    download the corresponding atis file
    from http://www-etud.iro.umontreal.ca/~mesnilgr/atis/
    '''
    print ('Downloading data from %s' % origin)
    urllib.urlretrieve(origin, destination)


# data loading functions
def atisfold(fold):
    assert fold in range(5)
    filename = os.path.join(PREFIX, 'ml-bootcamp/atis/atis.fold'+str(fold)+'.pkl.gz')
    print(filename)
    f = gzip.open(filename, 'rb')
    train_set, valid_set, test_set, dicts = pickle.load(f,encoding='latin1')
    return train_set, valid_set, test_set, dicts
def shuffle(lol, seed):
    '''
    lol :: list of list as input
    seed :: seed the shuffling

    shuffle inplace each list in the same order
    '''
    for l in lol:
        random.seed(seed)
        random.shuffle(l)

def contextwin(l, win):
    '''
    win :: int corresponding to the size of the window
    given a list of indexes composing a sentence

    l :: array containing the word indexes

    it will return a list of list of indexes corresponding
    to context windows surrounding each word in the sentence
    '''
    assert (win % 2) == 1
    assert win >= 1
    l = list(l)

    lpadded = win // 2 * [-1] + l + win // 2 * [-1]
    out = [lpadded[i:(i + win)] for i in range(len(l))]

    assert len(out) == len(l)
    return out
def conlleval(p, g, w, filename):
    '''
    INPUT:
    p :: predictions
    g :: groundtruth
    w :: corresponding words
    OUTPUT:
    filename :: name of the file where the predictions
    are written. it will be the input of conlleval.pl script
    for computing the performance in terms of precision
    recall and f1 score
    '''
    out = ''
    for sl, sp, sw in zip(g, p, w):
        out += 'BOS O O\n'
        for wl, wp, w in zip(sl, sp, sw):
            out += w + ' ' + wl + ' ' + wp + '\n'
        out += 'EOS O O\n\n'

    f = open(filename,'w')
    f.writelines(out)
    f.close()
    
    return get_perf(filename)

def get_perf(filename):
    ''' run conlleval.pl perl script to obtain
    precision/recall and F1 score '''
    _conlleval = os.path.join(PREFIX, 'ml-bootcamp/conlleval.pl')
    if not os.path.isfile(_conlleval):
        #download('http://www-etud.iro.umontreal.ca/~mesnilgr/atis/conlleval.pl') 
        os.system('wget https://www.comp.nus.edu.sg/%7Ekanmy/courses/practicalNLP_2008/packages/conlleval.pl')
        os.chmod('conlleval.pl', stat.S_IRWXU) # give the execute permissions

    proc = subprocess.Popen(["perl", _conlleval], stdin=subprocess.PIPE, stdout=subprocess.PIPE)
    stdout, _ = proc.communicate(open(filename).read().encode('utf-8'))

    for line in stdout.decode().split('\n'):
        if 'accuracy' in line:
            out = line.split()
            break
    
    # out = ['accuracy:', '16.26%;', 'precision:', '0.00%;', 'recall:', '0.00%;', 'FB1:', '0.00']
    
    precision = float(out[3][:-2])
    recall    = float(out[5][:-2])
    f1score   = float(out[7])

    return {'p':precision, 'r':recall, 'f1':f1score}

def get_perfo(filename):
    ''' 
    work around for using a PERL script in python
    dirty but still works.
    '''
    tempfile = str(random.randint(1,numpy.iinfo('i').max)) + '.txt'
    if not isfile(PREFIX + 'conlleval.pl'):
        os.system('wget https://www.comp.nus.edu.sg/%7Ekanmy/courses/practicalNLP_2008/packages/conlleval.pl')
        #download('http://www-etud.iro.umontreal.ca/~mesnilgr/atis/conlleval.pl') 
        chmod('conlleval.pl', stat.S_IRWXU) # give the execute permissions
    if len(PREFIX) > 0:
        chmod(PREFIX + 'conlleval.pl', stat.S_IRWXU) # give the execute permissions
        cmd = PREFIX + 'conlleval.pl < %s | grep accuracy > %s'%(filename,tempfile)
    else:
        cmd = './conlleval.pl < %s | grep accuracy > %s'%(filename,tempfile)
    print (cmd)
    out = os.system(cmd)
    out = open(tempfile).readlines()[0].split()
    os.system('rm %s'%tempfile)
    precision = float(out[6][:-2])
    recall    = float(out[8][:-2])
    f1score   = float(out[10])
    return {'p':precision, 'r':recall, 'f1':f1score}

def arraysentence2string(arr):
    return " ".join([idx2word[x] for x in arr if x > 0])

def arraylabels2string(arr):
    return " ".join([idx2label[x] for x in arr if x > 0])

# %% [markdown]
# # Load the data

# %%
# load the dataset
train_set, valid_set, test_set, dic = atisfold(0)
import six

idx2label = dict((k, v) for v, k in six.iteritems(dic['labels2idx']))
idx2word = dict((k, v) for v, k in six.iteritems(dic['words2idx']))

train_lex, train_ne, train_y = train_set
valid_lex, valid_ne, valid_y = valid_set
test_lex, test_ne, test_y = test_set

vocsize = len(dic['words2idx'])
print ("Dictionary size: "+str(vocsize))
nclasses = len(dic['labels2idx'])
print ("Number of class labels: "+str(nclasses))
nsentences = len(train_lex)

groundtruth_valid = list(list(map(lambda x: idx2label[x], y)) for y in valid_y)
words_valid = list(list(map(lambda x: idx2word[x], w)) for w in valid_lex)
groundtruth_test = list(list(map(lambda x: idx2label[x], y)) for y in test_y)
words_test = list(list(map(lambda x: idx2word[x], w)) for w in test_lex)
# Out:
# /home/i311008/ml-bootcamp/atis/atis.fold0.pkl.gz
# Dictionary size: 572
# Number of class labels: 127

# %%
print (train_lex)
# Out:
#        384, 358, 496], dtype=int32), array([554, 194,  50,  66, 463,  20, 208, 351, 502, 128], dtype=int32), array([554,   3, 481,  99, 194, 208, 332, 569, 502, 307], dtype=int32), array([232, 542, 502, 196, 137, 502, 379], dtype=int32), array([232, 565, 273, 502, 196, 208, 379, 502,  64], dtype=int32), array([143, 379,  29], dtype=int32), array([383, 276,  32,  66, 194, 208, 351,  88, 502, 376, 358, 546], dtype=int32), array([177, 481, 405,  45,   9], dtype=int32), array([439, 301, 481, 288, 386, 208, 128, 502,  69], dtype=int32), array([554, 157, 175, 453, 200], dtype=int32), array([232, 542, 502, 196, 208,  77, 502, 415, 205], dtype=int32), array([439, 301, 481, 194, 208,  69, 502, 376], dtype=int32), array([554,  50, 481, 267, 176, 194, 208, 137, 502,  64], dtype=int32), array([439, 301, 194, 208,  77, 502, 415, 205], dtype=int32), array([232, 559, 331,  13,  93,  62, 332, 569], dtype=int32), array([439, 301, 481, 194, 208,  69, 502, 423], dtype=int32), array([439, 301, 481, 194, 270, 208, 287, 186], dtype=int32), array([554, 241, 481, 165, 193, 570, 221, 270,  77, 222, 502, 376], dtype=int32), array([232, 565, 273, 502, 196, 208,  77, 502,  69, 383, 473, 301, 554,
#         50, 481, 501, 353, 481, 194], dtype=int32), array([194,  40, 183, 208, 137, 502, 351], dtype=int32), array([439, 301,  32, 194, 208, 379, 502,  69, 557, 268, 496,  19,   8,
#        350, 384], dtype=int32), array([ 89, 570, 212, 301, 481, 174, 193, 358, 546, 208, 543, 502,  64,  21], dtype=int32), array([554, 241, 481, 444,  23,  66, 502, 196, 358, 208, 379, 502,  69], dtype=int32), array([554, 194, 213, 208, 415, 205, 502,  77,  40, 268,  19,   8, 350], dtype=int32), array([439, 301, 481, 194, 208,  77, 502,  64], dtype=int32), array([554,  50, 481, 321, 194, 208, 376, 502, 128, 215, 358,  37,  26], dtype=int32), array([276, 127, 194, 208,  77, 502, 351, 536, 530,  26], dtype=int32), array([156, 570, 221,  13, 193, 208,  64, 502,  97, 343,  94, 334, 317], dtype=int32), array([383, 189,  13, 193, 358, 136, 208, 376, 502, 415, 205,  40, 212,
#        301, 481, 193, 348], dtype=int32), array([232, 331,  13, 193, 208, 376, 502, 128], dtype=int32), array([232, 565, 273, 502, 196, 208,  64, 502, 376], dtype=int32), array([439, 301, 410, 515, 183, 208, 332, 569, 502, 307], dtype=int32), array([276, 481, 339, 194, 358, 546, 249, 424, 208, 307, 502, 543,  60,
#        234, 543,  73,  11,  35,  40,  11, 384], dtype=int32), array([439, 301, 481, 194, 334, 518,  73, 376,  40, 415, 205], dtype=int32), array([439, 301,  32, 481, 530,  26, 194, 270, 128], dtype=int32), array([439, 301, 321, 194, 208, 506], dtype=int32)]

# %%
words_valid
# Out:
# [['what',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'delta',
#   'flight',
#   'DIGITDIGITDIGITDIGIT',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'salt',
#   'lake',
#   'city'],
#  ['i', 'want', 'to', 'go', 'from', 'boston', 'to', 'atlanta', 'on', 'monday'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'philadelphia',
#   'and',
#   'i',
#   "'m",
#   'looking',
#   'for',
#   'the',
#   'cheapest',
#   'fare'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'toronto',
#   'to',
#   'montreal',
#   'reaching',
#   'montreal',
#   'early',
#   'on',
#   'friday'],
#  ['show',
#   'me',
#   'the',
#   'evening',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'baltimore'],
#  ['tell', 'me', 'distance', 'from', 'orlando', 'airport', 'to', 'the', 'city'],
#  ['what', 'is', 'restriction', 'ap80'],
#  ['what',
#   'is',
#   'the',
#   'lowest',
#   'cost',
#   'fare',
#   'that',
#   'delta',
#   'has',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco'],
#  ['flight', 'DIGITDIGITDIGIT', 'from', 'cincinnati', 'to', 'dallas'],
#  ['now',
#   'i',
#   'need',
#   'a',
#   'one',
#   'way',
#   'flight',
#   'from',
#   'pittsburgh',
#   'to',
#   'denver'],
#  ['display',
#   'all',
#   'flights',
#   'leaving',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego',
#   'on',
#   'us',
#   'air',
#   '<UNK>',
#   'over',
#   'in',
#   'washington',
#   'dc'],
#  ['list',
#   'all',
#   'nonstop',
#   'flights',
#   'on',
#   'tuesday',
#   'before',
#   'noon',
#   'from',
#   'charlotte',
#   'to',
#   'baltimore'],
#  ['show',
#   'me',
#   'the',
#   'lowest',
#   '<UNK>',
#   'fare',
#   'from',
#   'dallas',
#   'to',
#   'baltimore'],
#  ['what',
#   'is',
#   'the',
#   'cheapest',
#   'coach',
#   'flight',
#   'between',
#   'dallas',
#   'and',
#   'baltimore',
#   'leaving',
#   'august',
#   'tenth'],
#  ['does', 'midwest', 'express', 'serve', 'philadelphia'],
#  ['what',
#   'flights',
#   'on',
#   'united',
#   'leave',
#   'la',
#   'guardia',
#   'for',
#   'san',
#   'jose',
#   'and',
#   'arrive',
#   'around',
#   'DIGITDIGIT',
#   'pm'],
#  ['list',
#   'the',
#   'nonstop',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc'],
#  ['how',
#   'much',
#   'does',
#   'flight',
#   'ua',
#   'DIGITDIGITDIGIT',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'cost'],
#  ['what',
#   'kind',
#   'of',
#   'ground',
#   'transportation',
#   'is',
#   'available',
#   'in',
#   'las',
#   'vegas'],
#  ['what',
#   'are',
#   'the',
#   'nonstop',
#   'flights',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'burbank',
#   'arriving',
#   'on',
#   'saturday',
#   'may',
#   'twenty',
#   'two'],
#  ['list',
#   'the',
#   'morning',
#   'flights',
#   'at',
#   'a',
#   'DIGITDIGITDIGIT',
#   'dollars',
#   'from',
#   'atlanta',
#   'to',
#   'boston'],
#  ['what',
#   'is',
#   'the',
#   'fare',
#   'going',
#   'from',
#   'atlanta',
#   'to',
#   'boston',
#   'one',
#   'way',
#   'on',
#   'november',
#   'seventh'],
#  ['is',
#   'there',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'stops',
#   'over',
#   'in',
#   'denver'],
#  ['find',
#   'travel',
#   'arrangements',
#   'for',
#   'a',
#   'round',
#   'trip',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'pittsburgh',
#   'after',
#   'DIGIT',
#   "o'clock",
#   'pm',
#   'before',
#   'DIGITDIGIT',
#   "o'clock",
#   'pm'],
#  ['can',
#   'i',
#   'have',
#   'a',
#   'list',
#   'of',
#   'all',
#   'the',
#   'thursday',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'atlanta',
#   'that',
#   'leave',
#   'after',
#   'DIGIT',
#   'pm'],
#  ['what',
#   'flights',
#   'do',
#   'you',
#   'have',
#   'in',
#   'the',
#   'morning',
#   'of',
#   'september',
#   'twentieth',
#   'on',
#   'united',
#   'airlines',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'and',
#   'a',
#   'stopover',
#   'in',
#   'denver'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'that',
#   'leaves',
#   'early',
#   'in',
#   'the',
#   'morning'],
#  ['round', 'trip', 'houston', 'to', 'las', 'vegas', 'nonstop'],
#  ['flight', 'information', 'from', 'san', 'francisco', 'to', 'pittsburgh'],
#  ['give',
#   'me',
#   'flights',
#   'without',
#   'fares',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore'],
#  ['on',
#   'monday',
#   'i',
#   'would',
#   'like',
#   'to',
#   'travel',
#   'from',
#   'charlotte',
#   'north',
#   'carolina',
#   'to',
#   'phoenix',
#   'arizona',
#   'i',
#   'would',
#   'like',
#   'to',
#   'arrive',
#   'in',
#   'phoenix',
#   'before',
#   'DIGIT',
#   'pm'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'find',
#   'flights',
#   'from',
#   'columbus',
#   'to',
#   'minneapolis',
#   'on',
#   'monday',
#   'june',
#   'fourteenth',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'or',
#   'in',
#   'the',
#   'evening',
#   'sunday',
#   'june',
#   'thirteenth',
#   'thank',
#   'you'],
#  ['what', 'is', 'airline', 'ff'],
#  ['give', 'me', 'flights', 'from', 'pittsburgh', 'to', 'baltimore'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'on',
#   'friday'],
#  ['airline', 'that', 'stands', 'for', 'dl'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'houston',
#   'and',
#   'from',
#   'houston',
#   'to',
#   'dallas'],
#  ['how',
#   'many',
#   'first',
#   'class',
#   'flights',
#   'does',
#   'delta',
#   'have',
#   'today'],
#  ['how',
#   'many',
#   'first',
#   'class',
#   'flights',
#   'does',
#   'united',
#   'have',
#   'leaving',
#   'from',
#   'all',
#   'cities',
#   'today'],
#  ['what',
#   'flights',
#   'does',
#   'delta',
#   'have',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco'],
#  ['list', 'ground', 'transportation', 'in', 'detroit'],
#  ['information',
#   'on',
#   'afternoon',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'denver'],
#  ['list', 'the', 'morning', 'flights', 'between', 'atlanta', 'and', 'dallas'],
#  ['show', 'me', 'the', 'flights', 'from', 'boston', 'to', 'pittsburgh'],
#  ['give',
#   'me',
#   'the',
#   'latest',
#   'flight',
#   'tomorrow',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'milwaukee',
#   'to',
#   'tacoma'],
#  ['nonstop', 'flights', 'seattle', 'to', 'boston'],
#  ['what',
#   'time',
#   'is',
#   'the',
#   'last',
#   'flight',
#   'from',
#   'washington',
#   'to',
#   'san',
#   'francisco'],
#  ['us',
#   'DIGITDIGITDIGITDIGIT',
#   'baltimore',
#   'to',
#   'philadelphia',
#   'what',
#   'is',
#   'the',
#   'round',
#   'trip',
#   'fare'],
#  ['please',
#   'show',
#   'me',
#   'any',
#   'united',
#   'flights',
#   '<UNK>',
#   'connections',
#   'between',
#   'boston',
#   'and',
#   'san',
#   'francisco',
#   'at',
#   'DIGIT',
#   'in',
#   'the',
#   'evening'],
#  ['list',
#   'all',
#   'the',
#   'flights',
#   'that',
#   'fly',
#   'into',
#   'general',
#   'mitchell',
#   'international'],
#  ['display',
#   'all',
#   'flights',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego',
#   'on',
#   'us',
#   'air',
#   'stopping',
#   'over',
#   'in',
#   'denver'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'find',
#   'a',
#   'us',
#   'air',
#   'flight',
#   'from',
#   'orlando',
#   'to',
#   'cleveland',
#   'that',
#   'arrives',
#   'around',
#   'DIGITDIGIT',
#   "o'clock",
#   'in',
#   'the',
#   'evening'],
#  ['what', "'s", 'the', 'airport', 'at', 'orlando'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'stopping',
#   'in',
#   'dallas',
#   'on',
#   'american',
#   'airlines'],
#  ['what', 'do', 'these', 'cost'],
#  ['what', 'airline', 'uses', 'the', 'code', 'hp'],
#  ['please',
#   'tell',
#   'me',
#   'the',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'philadelphia',
#   'next',
#   'thursday'],
#  ['show',
#   'all',
#   'flights',
#   'with',
#   'first',
#   'class',
#   'from',
#   'baltimore',
#   'to',
#   'dallas'],
#  ['information', 'on', 'flights', 'from', 'denver', 'to', 'philadelphia'],
#  ['i',
#   'now',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'jose',
#   'to',
#   'houston',
#   'leaving',
#   'on',
#   'sunday',
#   'the',
#   'fourth'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'between',
#   'atlanta',
#   'and',
#   'washington',
#   'dc',
#   'for',
#   'wednesdays'],
#  ['do',
#   'you',
#   'have',
#   'any',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'dallas',
#   'fort',
#   'worth',
#   'that',
#   'stop',
#   'over',
#   'in',
#   'philadelphia'],
#  ['give', 'me', 'a', 'list', 'of', 'airlines', 'in', 'pittsburgh'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'which',
#   'leave',
#   'next',
#   'saturday',
#   'afternoon'],
#  ['what',
#   'are',
#   'the',
#   'evening',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore'],
#  ['what',
#   'flights',
#   'between',
#   'dfw',
#   'and',
#   'oakland',
#   'arrive',
#   'in',
#   'oakland',
#   'between',
#   'DIGITDIGITDIGITDIGIT',
#   'am',
#   'and',
#   'DIGITDIGIT',
#   'pm'],
#  ['on',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'atlanta',
#   'that',
#   'leaves',
#   'before',
#   'DIGIT',
#   'am',
#   'is',
#   'there',
#   '<UNK>',
#   'a',
#   'flight'],
#  ['what', 'ground', 'transportation', 'can', 'i', 'take', 'into', 'boston'],
#  ['please',
#   'show',
#   'me',
#   'the',
#   'round',
#   'trip',
#   'flights',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'toronto'],
#  ['show', 'me', 'all', 'flights', 'from', 'baltimore', 'to', 'philadelphia'],
#  ['all',
#   'flights',
#   'and',
#   'fares',
#   'from',
#   'pittsburgh',
#   'to',
#   'dallas',
#   'round',
#   'trip',
#   'after',
#   'DIGITDIGIT',
#   'pm',
#   'less',
#   'than',
#   'DIGITDIGITDIGITDIGIT',
#   'dollars'],
#  ['does', 'us', 'air', 'fly', 'from', 'dc', 'to', 'dallas'],
#  ['what', 'does', 'code', 'yn', 'mean'],
#  ['list',
#   'all',
#   'daily',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'oakland',
#   'using',
#   'delta',
#   'airlines'],
#  ['what', 'does', 'ua', 'stand', 'for'],
#  ['please',
#   'list',
#   'the',
#   'flights',
#   'from',
#   'chicago',
#   'to',
#   'kansas',
#   'city'],
#  ['i', 'would', 'like', 'to', 'fly', 'from', 'boston', 'to', 'atlanta'],
#  ['which', 'airlines', 'fly', 'from', 'boston', 'to', 'washington'],
#  ['show', 'me', 'flights', 'from', 'baltimore', 'to', 'boston'],
#  ['are',
#   'there',
#   'any',
#   'thrift',
#   'economy',
#   'flights',
#   'to',
#   'san',
#   'francisco',
#   'from',
#   'boston'],
#  ['what', 'flights', 'leave', 'from', 'nashville', 'to', 'phoenix'],
#  ['display',
#   'all',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'boston',
#   'on',
#   'july',
#   'thirtieth'],
#  ['i',
#   'live',
#   'in',
#   'montreal',
#   'and',
#   'i',
#   'want',
#   'to',
#   'travel',
#   'to',
#   'chicago',
#   'then',
#   'indianapolis',
#   'and',
#   'then',
#   'return',
#   '<UNK>'],
#  ['show',
#   'me',
#   'fares',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'thursday',
#   'morning'],
#  ['show', 'me', 'the', 'latest', 'flight', 'from', 'denver', 'to', 'boston'],
#  ['are',
#   'there',
#   'any',
#   'flights',
#   'next',
#   'monday',
#   'morning',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco'],
#  ['show',
#   'all',
#   'flights',
#   'and',
#   'fares',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco'],
#  ['what',
#   'is',
#   'the',
#   'fare',
#   'on',
#   'american',
#   'airlines',
#   'flight',
#   'DIGITDIGITDIGIT',
#   'from',
#   'dallas',
#   'fort',
#   'worth',
#   'to',
#   'boston'],
#  ['what', 'flights', 'from', 'atlanta', 'to', 'washington'],
#  ['i',
#   "'m",
#   'interested',
#   'in',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh'],
#  ['does', 'midwest', 'express', 'serve', 'charlotte'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'on',
#   'july',
#   'twenty',
#   'fifth',
#   'DIGITDIGITDIGITDIGIT'],
#  ['on',
#   'april',
#   'eighth',
#   'i',
#   'would',
#   'like',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'from',
#   'charlotte',
#   'to',
#   'baltimore'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'saturday',
#   'to',
#   'san',
#   'francisco',
#   'from',
#   'dallas'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'friday',
#   'afternoon',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco'],
#  ['show', 'me', 'the', 'last', 'flight', 'from', 'love', 'field'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'arriving',
#   'in',
#   'baltimore',
#   'on',
#   'june',
#   'fourteenth'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'late',
#   'monday',
#   'evening',
#   'or',
#   'early',
#   'tuesday',
#   'morning'],
#  ['flights', 'from', 'phoenix', 'to', 'newark'],
#  ['does',
#   'the',
#   'phoenix',
#   'airport',
#   'have',
#   'ground',
#   'transportation',
#   'to',
#   'and',
#   'from',
#   'downtown'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'which',
#   'leave',
#   'pittsburgh',
#   'tomorrow',
#   'and',
#   'arrive',
#   'in',
#   'baltimore',
#   'after',
#   'DIGIT',
#   "o'clock",
#   'pm'],
#  ['what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'baltimore',
#   'leaving',
#   'tomorrow'],
#  ['phoenix', 'to', 'denver'],
#  ['chicago', 'to', 'milwaukee'],
#  ['please',
#   'show',
#   'me',
#   'the',
#   'return',
#   'flights',
#   'from',
#   'miami',
#   'to',
#   'new',
#   'york'],
#  ['how', 'many', 'booking', 'classes', 'are', 'there'],
#  ['flights', 'from', 'indianapolis', 'to', 'seattle'],
#  ['show', 'flights', 'between', 'toronto', 'and', 'san', 'francisco'],
#  ['show', 'me', 'the', 'cheapest', 'fare', 'in', 'the', 'database'],
#  ['flights',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'cleveland',
#   'on',
#   'wednesday',
#   'before',
#   'DIGIT',
#   'pm'],
#  ['show', 'me', 'all', 'the', 'flights', 'from', 'montreal', 'to', 'detroit'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'philadelphia',
#   'or',
#   'baltimore'],
#  ['i',
#   'want',
#   'the',
#   'flights',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego',
#   'that',
#   'stop',
#   'in',
#   'st.',
#   'louis'],
#  ['show',
#   'me',
#   'the',
#   'one',
#   'way',
#   'flights',
#   'from',
#   'detroit',
#   'to',
#   'westchester',
#   'county'],
#  ['flights', 'on', 'sunday', 'from', 'tampa', 'to', 'charlotte'],
#  ['i',
#   'want',
#   'to',
#   'find',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'boston',
#   'that',
#   'serves',
#   'a',
#   'meal'],
#  ['what',
#   'ground',
#   'transportation',
#   'is',
#   'there',
#   'from',
#   'the',
#   'airport',
#   'in',
#   'atlanta',
#   'to',
#   'downtown'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'denver',
#   'to',
#   'dallas',
#   'fort',
#   'worth',
#   'in',
#   'the',
#   '<UNK>'],
#  ['what',
#   'flights',
#   'does',
#   'us',
#   'air',
#   'have',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'on',
#   'tuesday'],
#  ['show',
#   'any',
#   'flights',
#   'leaving',
#   'san',
#   'francisco',
#   'on',
#   'sunday',
#   'and',
#   'arriving',
#   'in',
#   'pittsburgh'],
#  ['i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'at',
#   'DIGITDIGITDIGIT',
#   'am',
#   'and',
#   'arrive',
#   'in',
#   'denver',
#   'at',
#   'DIGITDIGITDIGITDIGIT',
#   'in',
#   'the',
#   'morning'],
#  ['what', 'is', 'hp'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'see',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta'],
#  ['i',
#   'need',
#   'to',
#   'take',
#   'ten',
#   'people',
#   'from',
#   'denver',
#   'to',
#   'phoenix',
#   'please',
#   'give',
#   'me',
#   'the',
#   'flights',
#   'during',
#   'the',
#   'week'],
#  ['find',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'that',
#   'makes',
#   'a',
#   'stopover',
#   'in',
#   'denver'],
#  ['list',
#   'the',
#   'number',
#   'of',
#   'flights',
#   'leaving',
#   'boston',
#   'for',
#   'dallas',
#   'fort',
#   'worth',
#   'before',
#   'DIGIT',
#   'am',
#   'in',
#   'the',
#   'morning'],
#  ['when',
#   'can',
#   'i',
#   'fly',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'on',
#   'a',
#   'saturday',
#   'morning'],
#  ['what',
#   "'s",
#   'the',
#   'lowest',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'dallas',
#   'to',
#   'any',
#   'city'],
#  ['may',
#   'i',
#   'have',
#   'a',
#   'listing',
#   'of',
#   'flights',
#   'on',
#   'monday',
#   'from',
#   'minneapolis',
#   'to',
#   'long',
#   'beach',
#   'california',
#   'please'],
#  ['please', 'show', 'me', 'all', 'the', 'flights', 'from', 'boston'],
#  ['i',
#   'want',
#   'to',
#   'travel',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'first',
#   'flight'],
#  ['cheapest', 'fare', 'from', 'memphis', 'to', 'seattle'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'see',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'please'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'friday',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston'],
#  ['list',
#   'all',
#   'the',
#   'landings',
#   'at',
#   'general',
#   'mitchell',
#   'international'],
#  ['what',
#   'flights',
#   'depart',
#   'from',
#   'charlotte',
#   'to',
#   'newark',
#   'that',
#   'leave',
#   'in',
#   'the',
#   'afternoon',
#   'or',
#   'leave',
#   'in',
#   'the',
#   'evening'],
#  ['i',
#   "'d",
#   'like',
#   'a',
#   'round',
#   'trip',
#   'ticket',
#   'from',
#   'los',
#   'angeles',
#   'to',
#   'tacoma',
#   'washington'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco'],
#  ['how',
#   'much',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'fly',
#   'on',
#   'american',
#   'from',
#   'dallas',
#   'to',
#   'baltimore'],
#  ['show', 'me', 'ground', 'transport', 'in', 'seattle'],
#  ['what',
#   'is',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'pittsburgh',
#   'one',
#   'way'],
#  ['what', 'is', 'restriction', 'ap', 'DIGITDIGIT'],
#  ['show',
#   'me',
#   'the',
#   'monday',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh'],
#  ['all',
#   'flights',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'on',
#   'thursday',
#   'arrival',
#   'by',
#   'DIGITDIGIT',
#   'am'],
#  ['what', 'flights', 'go', 'from', 'boston', 'to', 'atlanta'],
#  ['give',
#   'me',
#   'the',
#   'flights',
#   'leaving',
#   'denver',
#   'august',
#   'ninth',
#   'coming',
#   'back',
#   'to',
#   'boston'],
#  ['what', 'does', 'fare', 'code', 'qw', 'mean'],
#  ['what',
#   'are',
#   'the',
#   'flights',
#   'which',
#   'depart',
#   'from',
#   'san',
#   'francisco',
#   'fly',
#   'to',
#   'washington',
#   'via',
#   'indianapolis',
#   'and',
#   'arrive',
#   'by',
#   'DIGIT',
#   'pm'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'oakland',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'sunday'],
#  ['what', 'flights', 'are', 'there', 'from', 'denver', 'to', 'atlanta'],
#  ['please', 'list', 'flights', 'between', 'san', 'francisco', 'and', 'denver'],
#  ['hello',
#   'i',
#   'would',
#   'like',
#   'to',
#   'plan',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'airlines',
#   'from',
#   'boston',
#   'to',
#   'denver'],
#  ['show', 'me', 'the', 'flights', 'from', 'baltimore', 'to', 'oakland'],
#  ['what',
#   'flights',
#   'does',
#   'delta',
#   'have',
#   'from',
#   'denver',
#   'to',
#   'dallas',
#   'after',
#   'DIGIT'],
#  ['what',
#   'flights',
#   'go',
#   'from',
#   'newark',
#   'to',
#   'boston',
#   'after',
#   'DIGIT',
#   'pm'],
#  ['show',
#   'me',
#   'all',
#   'round',
#   'trip',
#   'flights',
#   'between',
#   'houston',
#   'and',
#   'las',
#   'vegas'],
#  ['please',
#   'list',
#   'the',
#   'flights',
#   'taking',
#   '<UNK>',
#   'and',
#   'landing',
#   'on',
#   'general',
#   'mitchell',
#   'international',
#   'airport'],
#  ['ground', 'transportation', 'for', 'st.', 'paul'],
#  ['i',
#   'would',
#   'like',
#   'information',
#   'on',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'leaving',
#   'after',
#   'DIGIT',
#   'pm',
#   'monday',
#   'night'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'book',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'denver'],
#  ['please',
#   'list',
#   'all',
#   'flights',
#   'that',
#   'leave',
#   'denver',
#   'before',
#   'noon',
#   'on',
#   'northwest',
#   'airlines'],
#  ['what',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'milwaukee',
#   'on',
#   'friday',
#   'on',
#   'american',
#   'airlines'],
#  ['flights', 'from', 'newark', 'new', 'jersey', 'to', 'cleveland', 'ohio'],
#  ['what',
#   'flights',
#   'leave',
#   'seattle',
#   'on',
#   'sunday',
#   'on',
#   'continental',
#   'after',
#   'DIGIT',
#   'pm'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'denver',
#   'on',
#   'weekdays'],
#  ['what',
#   'is',
#   'american',
#   "'s",
#   'schedule',
#   'of',
#   'morning',
#   'flights',
#   'to',
#   'atlanta'],
#  ['can',
#   'you',
#   'list',
#   'all',
#   'the',
#   'flights',
#   'between',
#   'phoenix',
#   'and',
#   'las',
#   'vegas'],
#  ['can',
#   'you',
#   'please',
#   'tell',
#   'me',
#   'the',
#   'type',
#   'of',
#   'aircraft',
#   'used',
#   'flying',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'on',
#   'eastern',
#   'flight',
#   'DIGITDIGITDIGIT',
#   'leaving',
#   'at',
#   'DIGITDIGITDIGIT'],
#  ['show',
#   'me',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'for',
#   'august',
#   'thirty',
#   'first',
#   'DIGITDIGITDIGITDIGIT'],
#  ['please',
#   'list',
#   'all',
#   'flights',
#   'on',
#   'united',
#   'airlines',
#   'out',
#   'of',
#   'denver',
#   'before',
#   'noon'],
#  ['list',
#   'all',
#   'flights',
#   'from',
#   'orlando',
#   'to',
#   'kansas',
#   'city',
#   'then',
#   'to',
#   'minneapolis'],
#  ['list',
#   'all',
#   'american',
#   'airlines',
#   'flight',
#   'from',
#   'milwaukee',
#   'to',
#   'phoenix',
#   'on',
#   'sunday'],
#  ['in',
#   'economy',
#   'class',
#   'from',
#   'dallas',
#   'to',
#   'baltimore',
#   'arriving',
#   'july',
#   'seventh',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'know',
#   'what',
#   "'s",
#   'the',
#   'cheapest',
#   'ticket',
#   'possible'],
#  ['i',
#   'wish',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'please',
#   'find',
#   'an',
#   'airline',
#   'for',
#   'me'],
#  ['find',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco'],
#  ['how', 'many', 'passengers', 'fit', 'on', 'a', '<UNK>'],
#  ['what',
#   'flight',
#   'do',
#   'you',
#   'have',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'on',
#   'the',
#   'evening',
#   'of',
#   'august',
#   'twenty',
#   'seventh'],
#  ['shortest',
#   'flight',
#   'from',
#   'ontario',
#   'california',
#   'to',
#   'orlando',
#   'florida'],
#  ['how', 'much', 'would', 'car', 'rental', 'cost', 'in', 'atlanta'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'miami',
#   'with',
#   'a',
#   'stop',
#   'in',
#   'denver'],
#  ['pm', 'flights', 'dallas', 'to', 'atlanta'],
#  ['i',
#   "'d",
#   'like',
#   'a',
#   'flight',
#   'on',
#   'american',
#   'from',
#   'newark',
#   'to',
#   'nashville'],
#  ['what',
#   'kind',
#   'of',
#   'ground',
#   'transportation',
#   'is',
#   'there',
#   '<UNK>',
#   'i',
#   'get',
#   'to',
#   'dallas'],
#  ['what', 'planes', 'does', 'united', 'use'],
#  ['give',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'los',
#   'angeles',
#   'thursday',
#   'evening'],
#  ['could',
#   'you',
#   'tell',
#   'me',
#   'what',
#   'the',
#   'earliest',
#   'flight',
#   'that',
#   'goes',
#   'between',
#   'atlanta',
#   'and',
#   'denver',
#   'is',
#   'which',
#   'serves',
#   'a',
#   'meal'],
#  ['show',
#   'me',
#   'the',
#   'latest',
#   'flight',
#   'on',
#   'wednesday',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'dc'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'sunday'],
#  ['give', 'me', 'flights', 'from', 'denver', 'to', 'baltimore'],
#  ['what', 'ground', 'transport', 'is', 'available', 'in', 'charlotte'],
#  ['how',
#   'long',
#   'does',
#   'it',
#   'take',
#   'to',
#   'get',
#   'from',
#   'atlanta',
#   'airport',
#   'into',
#   'the',
#   'city',
#   'of',
#   'atlanta'],
#  ['tell',
#   'me',
#   'about',
#   'ground',
#   'transportation',
#   'between',
#   'orlando',
#   'international',
#   'and',
#   'orlando'],
#  ['what',
#   'flights',
#   'are',
#   'there',
#   'on',
#   'continental',
#   'from',
#   'seattle',
#   'to',
#   'chicago'],
#  ['i', 'need', 'to', 'fly', 'leaving', 'philadelphia', 'to', 'atlanta'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'that',
#   'has',
#   'no',
#   'stops',
#   'from',
#   'washington',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'friday'],
#  ['give',
#   'me',
#   'a',
#   'flight',
#   'from',
#   'new',
#   'york',
#   'city',
#   'to',
#   'las',
#   'vegas',
#   'and',
#   'a',
#   'flight',
#   'from',
#   'memphis',
#   'to',
#   'las',
#   'vegas',
#   'that',
#   'arrive',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['list', 'flights', 'tomorrow', 'from', 'san', 'diego', 'to', 'phoenix'],
#  ['i',
#   'need',
#   'to',
#   'go',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'in',
#   'the',
#   'same',
#   'day',
#   'find',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston'],
#  ['show', 'me', 'the', 'flights', 'from', 'san', 'francisco', 'to', 'boston'],
#  ['on',
#   'august',
#   'thirtieth',
#   'please',
#   'schedule',
#   'me',
#   'on',
#   'a',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'early',
#   'in',
#   'the',
#   'morning'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'for',
#   'tomorrow',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'dc',
#   'late',
#   'the',
#   'twenty',
#   'fifth',
#   'or',
#   'early',
#   'the',
#   'twenty',
#   'sixth'],
#  ['what', 'limousine', 'service', 'in', 'toronto'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'ontario',
#   'to',
#   'memphis'],
#  ['i',
#   "'d",
#   'like',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'please'],
#  ['what', 'does', 'the', 'fare', 'code', 'f', 'mean'],
#  ['does',
#   'eastern',
#   'have',
#   'an',
#   'early',
#   'afternoon',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco'],
#  ['what',
#   'first',
#   'class',
#   'airplane',
#   'goes',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'and',
#   'stops',
#   'in',
#   'dallas',
#   'in',
#   'the',
#   'afternoon',
#   'on',
#   'monday'],
#  ['how',
#   'many',
#   'flights',
#   'has',
#   'continental',
#   'into',
#   'and',
#   'out',
#   'of',
#   'atlanta'],
#  ['what',
#   'is',
#   'the',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'united',
#   'airlines',
#   'flight',
#   'DIGITDIGIT'],
#  ['what',
#   'flights',
#   'depart',
#   'baltimore',
#   'and',
#   'arrive',
#   'by',
#   'DIGIT',
#   'pm',
#   'friday',
#   'in',
#   'san',
#   'francisco'],
#  ['what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'on',
#   'august',
#   'tenth'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'leaving',
#   'after',
#   'DIGIT',
#   'pm',
#   'on',
#   'friday'],
#  ['is',
#   'there',
#   'ground',
#   'transportation',
#   'from',
#   'the',
#   'boston',
#   'airport',
#   'to',
#   'downtown',
#   'boston'],
#  ['show', 'me', 'the', 'flights', 'from', 'baltimore', 'to', 'boston'],
#  ['what', 'are', 'the', 'flights', 'from', 'san', 'francisco', 'to', 'denver'],
#  ['list',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'charlotte',
#   'to',
#   'atlanta',
#   'that',
#   'return',
#   'around',
#   'DIGIT',
#   'pm'],
#  ['what',
#   'ground',
#   'transportation',
#   'is',
#   'available',
#   'in',
#   'san',
#   'francisco'],
#  ['list',
#   'all',
#   'the',
#   'flights',
#   'that',
#   'depart',
#   'from',
#   'general',
#   'mitchell',
#   'international'],
#  ['ground', 'transportation', 'in', 'denver'],
#  ['show', 'me', 'flights', 'leaving', 'from', 'dallas', 'to', 'baltimore'],
#  ['what',
#   'is',
#   'the',
#   'seating',
#   'capacity',
#   'of',
#   'a',
#   'boeing',
#   'DIGITDIGITDIGIT'],
#  ['what',
#   'is',
#   'the',
#   'first',
#   'class',
#   'fare',
#   'from',
#   'indianapolis',
#   'to',
#   'orlando'],
#  ['please',
#   'show',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'wednesday',
#   'morning',
#   'serving',
#   'breakfast'],
#  ['list',
#   'nonstop',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'oakland',
#   'that',
#   'depart',
#   'in',
#   'the',
#   'afternoon'],
#  ['what', 'is', 'the', 'first', 'flight', 'from', 'boston', 'to', 'atlanta'],
#  ['round',
#   'trip',
#   'flights',
#   'from',
#   'minneapolis',
#   'to',
#   'san',
#   'diego',
#   'coach',
#   'economy',
#   'fare'],
#  ['please',
#   'list',
#   'the',
#   'cheapest',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'baltimore',
#   'arriving',
#   'on',
#   'may',
#   'seventh'],
#  ['is', 'there', 'an', 'atlanta', 'flight', 'to', 'denver', 'connecting'],
#  ['please',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'oakland',
#   'to',
#   'dallas',
#   'on',
#   'sunday',
#   'morning'],
#  ['i',
#   'want',
#   'to',
#   'leave',
#   'before',
#   'DIGIT',
#   'in',
#   'the',
#   'morning',
#   'what',
#   'flight',
#   'should',
#   'i',
#   'take',
#   'to',
#   'atlanta',
#   'from',
#   'boston'],
#  ['flights', 'from', 'newark', 'to', 'boston'],
#  ['what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'jose',
#   'to',
#   'nashville',
#   'on',
#   'thursday',
#   'the',
#   'twentieth'],
#  ['does', 'delta', 'airlines', 'fly', 'from', 'pittsburgh', 'to', 'atlanta'],
#  ['list',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'st.',
#   'paul',
#   'to',
#   'san',
#   'jose'],
#  ['give',
#   'me',
#   'a',
#   'list',
#   'of',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'philadelphia',
#   'or',
#   'denver',
#   'to',
#   'philadelphia',
#   'or',
#   'pittsburgh',
#   'to',
#   'philadelphia'],
#  ['which', 'delta', 'flights', 'fly', 'from', 'boston', 'to', 'philadelphia'],
#  ['is',
#   'there',
#   'an',
#   'airline',
#   'that',
#   'has',
#   'a',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'a',
#   'stop',
#   'in',
#   'dallas'],
#  ['show', 'me', 'the', 'flights', 'arriving', 'at', 'love', 'field'],
#  ['friday', "'s", 'flights', 'between', 'newark', 'and', 'tampa'],
#  ['i',
#   'need',
#   'flights',
#   'that',
#   'arrive',
#   'in',
#   'baltimore',
#   'from',
#   'pittsburgh'],
#  ['morning',
#   'flights',
#   'out',
#   'of',
#   'san',
#   'francisco',
#   'arriving',
#   'boston',
#   'afternoon'],
#  ['which',
#   'airlines',
#   'have',
#   'flights',
#   'between',
#   'charlotte',
#   'and',
#   'newark'],
#  ['are',
#   'there',
#   'any',
#   'nonstop',
#   'flights',
#   'leaving',
#   'from',
#   'denver',
#   'arriving',
#   'in',
#   'baltimore',
#   'on',
#   'july',
#   'seventh'],
#  ['what',
#   "'s",
#   'the',
#   'cheapest',
#   'fare',
#   'for',
#   'a',
#   'round',
#   'trip',
#   'from',
#   'indianapolis',
#   'to',
#   'orlando',
#   'on',
#   'december',
#   'twenty',
#   'seventh'],
#  ['what',
#   'is',
#   'the',
#   'cheapest',
#   'way',
#   'to',
#   'fly',
#   'from',
#   'denver',
#   'to',
#   'oakland'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'dallas',
#   'tomorrow',
#   'morning'],
#  ['what', 'is', 'the', 'first', 'flight', 'from', 'boston', 'to', 'dallas'],
#  ['show',
#   'prices',
#   'for',
#   'all',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'dallas',
#   'on',
#   'july',
#   'twenty',
#   'ninth'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'tuesday',
#   'afternoon',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta'],
#  ['i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'and',
#   'i',
#   '<UNK>',
#   "'t",
#   'want',
#   'any',
#   'stopovers',
#   'and',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'only',
#   'during',
#   'the',
#   'afternoon'],
#  ['what',
#   'are',
#   'the',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'san',
#   'diego',
#   'on',
#   'wednesday',
#   'the',
#   'twelfth'],
#  ['i',
#   "'d",
#   'like',
#   'a',
#   'return',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'boston'],
#  ['i',
#   "'d",
#   'like',
#   'the',
#   'flights',
#   'from',
#   'san',
#   'jose',
#   'to',
#   'nashville',
#   'on',
#   'the',
#   'morning',
#   'of',
#   'friday',
#   'june',
#   'third'],
#  ['what', 'flights', 'are', 'there', 'from', 'minneapolis', 'to', 'chicago'],
#  ['i',
#   'want',
#   'a',
#   'flight',
#   'that',
#   'leaves',
#   'from',
#   'charlotte',
#   'to',
#   'newark',
#   'that',
#   'leaves',
#   'in',
#   'the',
#   'afternoon',
#   'or',
#   'evening'],
#  ['i',
#   "'d",
#   'like',
#   'a',
#   'first',
#   'class',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'on',
#   'january',
#   'first'],
#  ['are',
#   'there',
#   'any',
#   'nonstop',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'on',
#   'thursdays'],
#  ['am', 'flights', 'from', 'dallas', 'to', 'san', 'francisco'],
#  ['how',
#   'much',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'fly',
#   'on',
#   'delta',
#   'from',
#   'dallas',
#   'to',
#   'baltimore'],
#  ['how',
#   'much',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'go',
#   'from',
#   'downtown',
#   'to',
#   'logan',
#   'airport'],
#  ['may',
#   'i',
#   'have',
#   'a',
#   'listing',
#   'of',
#   'flights',
#   'from',
#   'minneapolis',
#   'to',
#   'long',
#   'beach',
#   'california',
#   'on',
#   'tuesday'],
#  ['please',
#   'tell',
#   'me',
#   'the',
#   'type',
#   'of',
#   'aircraft',
#   'used',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'before',
#   'DIGITDIGIT',
#   "o'clock",
#   'noon'],
#  ['find',
#   'any',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'oakland',
#   'stopping',
#   'in',
#   'denver'],
#  ['i',
#   'would',
#   'like',
#   'information',
#   'on',
#   'flights',
#   'from',
#   'oakland',
#   'california',
#   'to',
#   'dallas',
#   'leaving',
#   'on',
#   'sunday',
#   'morning'],
#  ['show',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'oakland',
#   'arriving',
#   'between',
#   'DIGITDIGIT',
#   'and',
#   'DIGIT',
#   "o'clock"],
#  ['may',
#   'i',
#   'have',
#   'a',
#   'listing',
#   'of',
#   'flights',
#   'from',
#   'long',
#   'beach',
#   'california',
#   'to',
#   'columbus',
#   'ohio',
#   'on',
#   'wednesday'],
#  ['show', 'me', 'all', 'flights', 'from', 'dallas', 'to', 'san', 'francisco'],
#  ['what',
#   'is',
#   'the',
#   'cost',
#   'of',
#   'united',
#   'airlines',
#   'flight',
#   'DIGITDIGITDIGIT',
#   'from',
#   'chicago',
#   'to',
#   'kansas',
#   'city',
#   'thursday',
#   'night'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'charlotte',
#   'which',
#   'will',
#   'get',
#   'me',
#   'into',
#   'charlotte',
#   'by',
#   'DIGIT',
#   'pm',
#   'or',
#   'as',
#   'soon',
#   '<UNK>',
#   'as',
#   'possible'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'baltimore',
#   'in',
#   'the',
#   'morning'],
#  ['DIGITDIGITDIGIT',
#   'am',
#   'flight',
#   'on',
#   'august',
#   'twenty',
#   'seventh',
#   'from',
#   'atlanta',
#   'to',
#   'dallas'],
#  ['i', 'would', 'like', 'a', 'flight', 'from', 'boston', 'to', 'atlanta'],
#  ['show', 'me', 'the', 'flights', 'into', 'love', 'field'],
#  ['show', 'me', 'flights', 'from', 'pittsburgh', 'to', 'san', 'francisco'],
#  ['i',
#   'would',
#   'like',
#   'an',
#   'early',
#   'morning',
#   'flight',
#   'from',
#   'chicago',
#   'into',
#   'seattle',
#   'on',
#   'june',
#   'first',
#   'on',
#   'continental',
#   'airline'],
#  ['what',
#   'kind',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'the',
#   'first',
#   'class',
#   'american',
#   'airlines',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'stopping',
#   'in',
#   'dallas'],
#  ['what',
#   'is',
#   'the',
#   'smallest',
#   'aircraft',
#   'available',
#   'flying',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'arriving',
#   'on',
#   'may',
#   'seventh'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'on',
#   'delta',
#   'from',
#   'atlanta',
#   'in',
#   'the',
#   'morning'],
#  ['show', 'me', 'the', 'flights', 'from', 'newark', 'to', 'los', 'angeles'],
#  ['what',
#   'is',
#   'the',
#   'latest',
#   'flight',
#   'from',
#   'washington',
#   'dc',
#   'to',
#   'denver'],
#  ['what', 'does', 'ewr', 'mean'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'that',
#   'goes',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'on',
#   'thursday'],
#  ['i',
#   'need',
#   'information',
#   'on',
#   'flights',
#   'from',
#   'kansas',
#   'city',
#   'missouri',
#   'to',
#   'salt',
#   'lake',
#   'city',
#   'utah',
#   'i',
#   'am',
#   'interested',
#   'in',
#   'only',
#   'those',
#   'flights',
#   'on',
#   'delta',
#   'airlines'],
#  ['show',
#   'me',
#   'the',
#   'airlines',
#   'that',
#   'fly',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'book',
#   'an',
#   'early',
#   'morning',
#   'flight',
#   'from',
#   'tampa',
#   'to',
#   'charlotte',
#   'on',
#   'april',
#   'sixth'],
#  ['philadelphia', 'to', 'boston', 'saturday'],
#  ['show',
#   'me',
#   'round',
#   'trip',
#   'fares',
#   'from',
#   'las',
#   'vegas',
#   'to',
#   'houston',
#   'nonstop'],
#  ['list', 'all', 'flights', 'from', 'denver', 'to', 'philadelphia'],
#  ['show', 'me', 'flights', 'from', 'all', 'airports', 'to', 'love', 'field'],
#  ['then',
#   'list',
#   'the',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'philadelphia',
#   'early',
#   'wednesday',
#   'morning',
#   'nonstop'],
#  ['what',
#   'is',
#   'american',
#   "'s",
#   'last',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'july',
#   'twenty',
#   'first'],
#  ['all', 'flights', 'before', 'DIGITDIGIT', 'am', 'boston', 'denver'],
#  ['are',
#   'there',
#   'any',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'which',
#   'stop',
#   'in',
#   'denver'],
#  ['what',
#   'american',
#   'airlines',
#   'flights',
#   'depart',
#   'milwaukee',
#   'for',
#   'phoenix',
#   'on',
#   'saturday',
#   'or',
#   'sunday'],
#  ['show',
#   'me',
#   'one',
#   'way',
#   'flights',
#   'from',
#   'tampa',
#   'to',
#   'st.',
#   'louis',
#   'departing',
#   'before',
#   'DIGITDIGIT',
#   'am'],
#  ['show',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'on',
#   'august',
#   'second',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'that',
#   'serves',
#   'a',
#   'meal'],
#  ['list',
#   'all',
#   'the',
#   'airlines',
#   'flying',
#   'between',
#   'washington',
#   'and',
#   'denver'],
#  ['list', 'the', 'shortest', 'flight', 'from', 'san', 'jose', 'to', 'houston'],
#  ['what',
#   'is',
#   'the',
#   'first',
#   'class',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'dallas'],
#  ['list',
#   'the',
#   'nonstop',
#   'flights',
#   'from',
#   'miami',
#   'to',
#   'new',
#   'york',
#   'on',
#   'a',
#   'sunday',
#   'along',
#   'with',
#   'the',
#   'fares',
#   'that',
#   'are',
#   'less',
#   'than',
#   'DIGITDIGITDIGIT',
#   'dollars'],
#  ['give',
#   'me',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'flights',
#   'between',
#   'boston',
#   'and',
#   'philadelphia',
#   'which',
#   'arrive',
#   'after',
#   'noon',
#   'on',
#   'a',
#   'tuesday'],
#  ['what',
#   'is',
#   'the',
#   'fare',
#   'on',
#   'november',
#   'seventh',
#   'going',
#   'one',
#   'way',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'oakland'],
#  ['what',
#   'flights',
#   'leaving',
#   'pittsburgh',
#   'arrive',
#   'in',
#   'denver',
#   'and',
#   'leave',
#   'after',
#   'say',
#   'DIGIT',
#   "o'clock",
#   'at',
#   'night'],
#  ['where', 'do', 'the', 'flights', 'from', 'boston', 'to', 'oakland', 'stop'],
#  ['give', 'me', 'a', 'list', 'of', 'airports', 'in', 'baltimore'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'find',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'oakland'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'baltimore',
#   'nonstop',
#   'arriving',
#   'at',
#   'DIGIT',
#   'pm',
#   'please'],
#  ['what',
#   'is',
#   'the',
#   'least',
#   'expensive',
#   'way',
#   'to',
#   'fly',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco'],
#  ['show',
#   'me',
#   'the',
#   'delta',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston'],
#  ['in',
#   'the',
#   'next',
#   'two',
#   'days',
#   'i',
#   'want',
#   'to',
#   'fly',
#   'from',
#   'nashville',
#   'to',
#   'san',
#   'jose',
#   'or',
#   'to',
#   'tacoma'],
#  ['is',
#   'there',
#   'a',
#   'DIGIT',
#   "o'clock",
#   'flight',
#   'from',
#   'washington',
#   'dc',
#   'to',
#   'denver'],
#  ['show', 'flights', 'from', 'pittsburgh', 'into', 'san', 'francisco'],
#  ['show', 'me', 'flights', 'from', 'denver', 'to', 'philadelphia'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'see',
#   'all',
#   'the',
#   'flights',
#   'with',
#   'their',
#   'fares',
#   'from',
#   'denver',
#   'to',
#   'atlanta'],
#  ['show',
#   'me',
#   'the',
#   'evening',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'on',
#   'wednesdays'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'on',
#   'friday',
#   'from',
#   'newark',
#   'to',
#   'tampa'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh',
#   'next',
#   'wednesday',
#   'night',
#   'after',
#   'DIGIT',
#   "o'clock"],
#  ['what', 'ground', 'transportation', 'is', 'available', 'at', 'baltimore'],
#  ['northwest', 'flights', 'with', 'stops', 'in', 'denver'],
#  ['one', 'way'],
#  ['what',
#   'flights',
#   'do',
#   'you',
#   'have',
#   'leaving',
#   'boston',
#   'going',
#   'to',
#   'san',
#   'francisco'],
#  ['yes',
#   'i',
#   'live',
#   'in',
#   'washington',
#   'and',
#   'i',
#   'want',
#   'to',
#   'make',
#   'a',
#   'trip',
#   'to',
#   'san',
#   'francisco',
#   'which',
#   'airlines',
#   'may',
#   'i',
#   'use',
#   'for',
#   'this',
#   'trip'],
#  ['how',
#   'far',
#   'is',
#   'it',
#   'from',
#   'salt',
#   'lake',
#   'city',
#   'airport',
#   'to',
#   'salt',
#   'lake',
#   'city'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'baltimore',
#   'coach',
#   'on',
#   'wednesday',
#   'about',
#   'DIGITDIGIT',
#   'noon'],
#  ['list', 'flights', 'from', 'denver', 'to', 'philadelphia'],
#  ['what',
#   'nonstop',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'oakland',
#   'to',
#   'pittsburgh'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'fort',
#   'worth',
#   'on',
#   'the',
#   'morning',
#   'of',
#   'july',
#   'tenth',
#   'DIGITDIGITDIGITDIGIT'],
#  ['what', 'are', 'the', 'flights', 'from', 'atlanta', 'to', 'baltimore'],
#  ['list',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'memphis',
#   'june',
#   'twenty',
#   'ninth'],
#  ['show', 'me', 'the', 'fares', 'from', 'dallas', 'to', 'san', 'francisco'],
#  ['flights', 'from', 'st.', 'paul', 'to', 'houston'],
#  ['can',
#   'you',
#   'show',
#   'me',
#   'flights',
#   'that',
#   'are',
#   'economy',
#   'class',
#   'from',
#   'baltimore',
#   'to',
#   'dallas'],
#  ['what', 'city', 'is', 'the', 'airport', 'mco', 'in'],
#  ['what',
#   'is',
#   'the',
#   'fare',
#   'on',
#   'november',
#   'seventh',
#   'going',
#   'one',
#   'way',
#   'from',
#   'dallas',
#   'to',
#   'san',
#   'francisco'],
#  ['how',
#   'can',
#   'i',
#   'get',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'and',
#   'back',
#   'in',
#   'the',
#   'same',
#   'day',
#   'and',
#   'have',
#   'the',
#   'most',
#   'hours',
#   'on',
#   'the',
#   'ground',
#   'in',
#   'atlanta'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'washington',
#   'dc',
#   'on',
#   'wednesdays'],
#  ['flight', 'numbers', 'from', 'columbus', 'to', 'minneapolis', 'tomorrow'],
#  ['show',
#   'me',
#   'all',
#   'first',
#   'class',
#   'prices',
#   'from',
#   'dallas',
#   'to',
#   'baltimore'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco'],
#  ['show',
#   'me',
#   'all',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'arriving',
#   'may',
#   'tenth'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'know',
#   'the',
#   'latest',
#   'flight',
#   'on',
#   'wednesday',
#   'you',
#   'have',
#   'leaving',
#   'from',
#   'oakland',
#   'to',
#   'salt',
#   'lake',
#   'city',
#   'which',
#   'offers',
#   'a',
#   'meal'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'on',
#   'monday'],
#  ['what',
#   'is',
#   'the',
#   'ground',
#   'transportation',
#   'available',
#   'in',
#   'the',
#   'city',
#   'of',
#   'philadelphia'],
#  ['explain', 'the', 'fare', 'code', 'q'],
#  ['well',
#   'i',
#   "'ll",
#   '<UNK>',
#   'last',
#   'time',
#   'tell',
#   'me',
#   'the',
#   'kind',
#   'of',
#   'aircraft',
#   'united',
#   'airlines',
#   'flies',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco',
#   'before',
#   'DIGITDIGIT',
#   "o'clock",
#   'in',
#   'the',
#   'morning'],
#  ['ground', 'transportation', 'atl', 'to', 'atlanta'],
#  ['i',
#   'need',
#   'the',
#   'cost',
#   'of',
#   'a',
#   'ticket',
#   'going',
#   'from',
#   'denver',
#   'to',
#   'baltimore',
#   'a',
#   'first',
#   'class',
#   'ticket',
#   'on',
#   'united',
#   'airlines'],
#  ['show',
#   'me',
#   'your',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'on',
#   'june',
#   'fourth'],
#  ['flights',
#   'from',
#   'baltimore',
#   'to',
#   'philadelphia',
#   'where',
#   'the',
#   'round',
#   'trip',
#   'fare',
#   'is',
#   'less',
#   'than',
#   'DIGITDIGITDIGITDIGIT',
#   'dollars'],
#  ['i',
#   'would',
#   'like',
#   'a',
#   'nonstop',
#   'flight',
#   'from',
#   'new',
#   'york',
#   'to',
#   'las',
#   'vegas',
#   'on',
#   'march',
#   'second'],
#  ['please',
#   'list',
#   'nonstop',
#   'flights',
#   'from',
#   'las',
#   'vegas',
#   'to',
#   'new',
#   'york',
#   'on',
#   'america',
#   'west'],
#  ['i',
#   'want',
#   'a',
#   'flight',
#   'originating',
#   'in',
#   'denver',
#   'going',
#   'to',
#   'pittsburgh',
#   'and',
#   'atlanta',
#   'in',
#   'either',
#   '<UNK>'],
#  ['show',
#   'flights',
#   'first',
#   'class',
#   'on',
#   'american',
#   'airlines',
#   'between',
#   'dallas',
#   'and',
#   'philadelphia'],
#  ['leave',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'leave',
#   'boston',
#   'approximately',
#   'DIGIT',
#   'pm'],
#  ['eastern',
#   'flight',
#   'DIGITDIGITDIGIT',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'leaving',
#   'at',
#   'DIGITDIGITDIGIT',
#   'what',
#   'type',
#   'of',
#   'aircraft',
#   'is',
#   'used',
#   'on',
#   'that',
#   'flight'],
#  ['okay',
#   'i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'from',
#   'atlanta',
#   'to',
#   'philadelphia'],
#  ['how',
#   'long',
#   'is',
#   'a',
#   'trip',
#   'from',
#   'philadelphia',
#   'airport',
#   'to',
#   'downtown',
#   'philadelphia'],
#  ['tuesday', 'morning', 'flights', 'between', 'charlotte', 'and', 'baltimore'],
#  ['what',
#   'is',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'stapleton',
#   'airport',
#   'for',
#   'tomorrow'],
#  ['how', 'do', 'i', 'get', 'downtown', 'from', 'the', 'toronto', 'airport'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'find',
#   'a',
#   'flight',
#   'that',
#   'goes',
#   'from',
#   'la',
#   'guardia',
#   'airport',
#   'to',
#   'san',
#   'jose',
#   'i',
#   'would',
#   'like',
#   'the',
#   'flight',
#   'to',
#   'be',
#   'on',
#   'united',
#   'airlines',
#   'and',
#   'arrive',
#   'in',
#   'san',
#   'jose',
#   'around',
#   'DIGITDIGIT',
#   'pm'],
#  ['what', 'time', 'does', 'flight', '<UNK>', 'DIGITDIGITDIGIT', 'depart'],
#  ['i', 'want', 'to', 'leave', 'boston', 'at', 'DIGITDIGITDIGIT'],
#  ['flight', 'from', 'dc', 'to', 'salt', 'lake', 'city'],
#  ['what', 'flights', 'from', 'miami', 'to', 'indianapolis', 'on', 'sunday'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'friday',
#   'leaving',
#   'after',
#   'DIGITDIGIT',
#   'noon'],
#  ['what', 'are', 'the', 'flights', 'from', 'denver', 'to', 'oakland'],
#  ['again',
#   'i',
#   'will',
#   'repeat',
#   'i',
#   'want',
#   'to',
#   'make',
#   'a',
#   'one',
#   'way',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'atlanta',
#   'will',
#   'you',
#   'tell',
#   'me',
#   'how',
#   'much',
#   'the',
#   'fares',
#   'are',
#   'i',
#   'would',
#   'like',
#   'the',
#   'cheapest',
#   'fare'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'on',
#   'june',
#   'sixteenth'],
#  ['the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'please',
#   'that',
#   'will',
#   'be',
#   'serving',
#   'a',
#   'meal'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'on',
#   'monday',
#   'morning'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'that',
#   'leaves',
#   'after',
#   'DIGIT',
#   'am'],
#  ['list',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'the',
#   'maximum',
#   'number',
#   'of',
#   'stops'],
#  ['i',
#   'would',
#   'like',
#   'a',
#   'flight',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'twa',
#   'with',
#   'a',
#   'stop',
#   'in',
#   'denver'],
#  ['can', 'i', 'rent', 'a', 'car', 'in', 'san', 'jose', 'too'],
#  ['show',
#   'me',
#   'the',
#   'one',
#   'way',
#   'fares',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'miami',
#   'nonstop'],
#  ['list',
#   'daily',
#   'flights',
#   'from',
#   'oakland',
#   'to',
#   'boston',
#   'using',
#   'delta',
#   'airlines'],
#  ['what', 'are', 'your', 'flights', 'from', 'denver', 'to', 'baltimore'],
#  ['are', 'there', 'delta', 'flights', 'leaving', 'atlanta'],
#  ['can',
#   'you',
#   'give',
#   'me',
#   'a',
#   'list',
#   'of',
#   'the',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'boston'],
#  ['on',
#   'a',
#   'breakfast',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'via',
#   'atlanta'],
#  ['fare', 'code', 'y', 'what', 'does', 'that', 'mean'],
#  ['what',
#   'type',
#   'of',
#   'aircraft',
#   'flies',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore'],
#  ['what',
#   "'s",
#   'the',
#   'cheapest',
#   'round',
#   'trip',
#   'fare',
#   'between',
#   'dallas',
#   'and',
#   'baltimore'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'on',
#   'september',
#   'fifteenth'],
#  ['show',
#   'me',
#   'all',
#   'the',
#   'prices',
#   'of',
#   'flights',
#   'from',
#   'baltimore',
#   'to',
#   'dallas'],
#  ['flights', 'from', 'indianapolis', 'nashville', 'memphis', 'to', 'seattle'],
#  ['list',
#   'all',
#   'flights',
#   'on',
#   'continental',
#   'which',
#   'leave',
#   'seattle',
#   'and',
#   'arrive',
#   'in',
#   'chicago',
#   'departing',
#   'on',
#   'sunday',
#   'after',
#   'DIGITDIGITDIGIT',
#   'pm'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'baltimore',
#   'what',
#   'time',
#   'are',
#   'the',
#   'flights',
#   'in',
#   'the',
#   'afternoon'],
#  ['i',
#   "'d",
#   'like',
#   'information',
#   'on',
#   'a',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'a',
#   'morning',
#   'flight'],
#  ['i',
#   'need',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'philadelphia'],
#  ['show',
#   'me',
#   'one',
#   'way',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'orlando',
# ...
#   'on',
#   'delta',
#   'airline'],
#  ['please',
#   'list',
#   'the',
#   'friday',
#   'night',
#   'flights',
#   'from',
#   'st.',
#   'paul',
#   'to',
#   'kansas',
#   'city'],
#  ['what', 'does', 'co', 'mean'],
#  ['now', 'get', 'me', 'from', 'pittsburgh', 'to', 'denver'],
#  ['could',
#   'you',
#   'please',
#   'tell',
#   'me',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco'],
#  ['what', 'does', 'ewr', 'mean'],
#  ['show', 'me', 'flights', 'from', 'dallas', 'to', 'baltimore'],
#  ['can',
#   'you',
#   'give',
#   'me',
#   'the',
#   'latest',
#   'flight',
#   'from',
#   'atlanta',
#   'to',
#   'denver',
#   'on',
#   'july',
#   'seventh'],
#  ['i',
#   'would',
#   'like',
#   'a',
#   'us',
#   'air',
#   'flight',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'denver',
#   'please'],
#  ['show',
#   'flights',
#   'leaving',
#   'miami',
#   'to',
#   'cleveland',
#   'on',
#   'us',
#   'air',
#   'that',
#   'leave',
#   'after',
#   'noon'],
#  ['show',
#   'me',
#   'the',
#   'airlines',
#   'that',
#   'fly',
#   'between',
#   'toronto',
#   'and',
#   'denver'],
#  ['find',
#   'a',
#   'flight',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'boston',
#   'on',
#   'wednesday'],
#  ['list',
#   'all',
#   'tuesday',
#   'night',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver'],
#  ['what', 'airlines', 'fly', 'from', 'boston', 'to', 'pittsburgh'],
#  ['tell',
#   'me',
#   'about',
#   'flights',
#   'from',
#   'toronto',
#   'to',
#   'salt',
#   'lake',
#   'city',
#   'leaving',
#   'after',
#   'DIGITDIGITDIGIT',
#   'pm'],
#  ['what',
#   'does',
#   'it',
#   'cost',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'oakland',
#   'on',
#   'united',
#   'airlines'],
#  ['show',
#   'business',
#   'class',
#   'fares',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'denver',
#   'on',
#   'united',
#   'airlines'],
#  ['how',
#   'much',
#   'is',
#   'a',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'memphis',
#   'to',
#   'seattle'],
#  ['flights', 'from', 'washington', 'dc', 'to', 'denver'],
#  ['list',
#   'nonstop',
#   'flights',
#   'from',
#   'houston',
#   'to',
#   'dallas',
#   'which',
#   'arrive',
#   'after',
#   'DIGIT',
#   'pm'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'see',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia'],
#  ['round',
#   'trip',
#   'fares',
#   'from',
#   'pittsburgh',
#   'to',
#   'philadelphia',
#   'under',
#   'DIGITDIGITDIGITDIGIT',
#   'dollars'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'breakfast',
#   'flight',
#   'from',
#   'philadelphia',
#   'to',
#   'fort',
#   'worth'],
#  ['show',
#   'me',
#   'fares',
#   'for',
#   'flights',
#   'from',
#   'minneapolis',
#   'to',
#   'seattle',
#   'on',
#   'july',
#   'first',
#   'DIGITDIGITDIGITDIGIT'],
#  ['i', 'need', 'a', 'flight', 'on', 'friday', 'from', 'newark', 'to', 'tampa'],
#  ['what', 'are', 'all', 'flights', 'from', 'boston', 'to', 'denver'],
#  ['what',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'newark',
#   'after',
#   'DIGITDIGITDIGITDIGIT',
#   'pm'],
#  ['i',
#   'need',
#   'information',
#   'for',
#   'flights',
#   'leaving',
#   'san',
#   'francisco',
#   'on',
#   'thursday',
#   'evening',
#   'and',
#   'returning',
#   'to',
#   'boston'],
#  ['find',
#   'travel',
#   'arrangements',
#   'for',
#   'a',
#   'one',
#   'way',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'pittsburgh'],
#  ['what',
#   'type',
#   'of',
#   'aircraft',
#   'leaves',
#   'from',
#   'boston',
#   'to',
#   'washington',
#   'dc',
#   'at',
#   'DIGIT',
#   'am'],
#  ['pittsburgh', 'to', 'denver'],
#  ['find',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'fare',
#   'from',
#   'boston',
#   'to',
#   'oakland'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'westchester',
#   'county'],
#  ['on',
#   'may',
#   'four',
#   'atlanta',
#   'to',
#   'denver',
#   'delta',
#   'flight',
#   'DIGITDIGITDIGIT'],
#  ['what',
#   'is',
#   'the',
#   'thrift',
#   'economy',
#   'flight',
#   'fare',
#   'from',
#   'washington',
#   'to',
#   'san',
#   'francisco'],
#  ['all', 'flights', 'from', 'sfo', 'to', 'long', 'beach'],
#  ['please',
#   'list',
#   'the',
#   'shortest',
#   'one',
#   'stop',
#   'flight',
#   'from',
#   'ontario',
#   'california',
#   'to',
#   'orlando',
#   'florida'],
#  ['please',
#   'show',
#   'me',
#   'airlines',
#   'with',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'denver',
#   'early',
#   'am',
#   'on',
#   'tuesday'],
#  ['hi', 'i', "'d", 'like', 'a', 'flight', 'from', 'tampa', 'to', 'montreal'],
#  ['is',
#   'there',
#   'a',
#   'limousine',
#   'service',
#   'available',
#   'from',
#   'the',
#   'pittsburgh',
#   'airport'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'that',
#   'go',
#   'from',
#   'san',
#   'diego',
#   'to',
#   'newark',
#   'new',
#   'jersey'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'in',
#   'the',
#   'morning',
#   'to',
#   'arrive',
#   'in',
#   'baltimore',
#   'from',
#   'boston'],
#  ['show', 'me', 'all', 'the', 'types', 'of', 'aircraft'],
#  ['could',
#   'you',
#   'please',
#   'find',
#   'me',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'oakland'],
#  ['list',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco',
#   'via',
#   'dallas'],
#  ['can',
#   'you',
#   'list',
#   'all',
#   'flights',
#   'departing',
#   'from',
#   'toronto',
#   'and',
#   'landing',
#   'in',
#   'san',
#   'diego',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'denver'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'baltimore',
#   'in',
#   'first',
#   'class'],
#  ['show', 'me', 'the', 'flights', 'from', 'chicago', 'to', 'indianapolis'],
#  ['flights', 'from', 'indianapolis', 'to', 'seattle', 'washington'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'with',
#   'a',
#   'stop',
#   'in',
#   'atlanta'],
#  ['is',
#   'there',
#   'a',
#   'flight',
#   'between',
#   'san',
#   'francisco',
#   'and',
#   'boston',
#   'with',
#   'a',
#   'stopover',
#   'at',
#   'dallas',
#   'fort',
#   'worth'],
#  ['do',
#   'you',
#   'have',
#   'flights',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'toronto',
#   'on',
#   'monday'],
#  ['show', 'me', 'flights', 'from', 'denver', 'to', 'dc', 'on', 'wednesday'],
#  ['i',
#   'would',
#   'like',
#   'a',
#   'nonstop',
#   'flight',
#   'from',
#   'st.',
#   'petersburg',
#   'to',
#   'charlotte',
#   'leaving',
#   'in',
#   'the',
#   'afternoon'],
#  ['find',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'atlanta',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'pittsburgh'],
#  ['what',
#   'is',
#   'the',
#   'last',
#   'flight',
#   'out',
#   'of',
#   'pittsburgh',
#   'to',
#   'boston',
#   'in',
#   'the',
#   'evening',
#   'on',
#   'tuesdays'],
#  ['what',
#   'flights',
#   'from',
#   'las',
#   'vegas',
#   'to',
#   'montreal',
#   'on',
#   'saturday'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'on',
#   'july',
#   'twenty',
#   'fifth',
#   'DIGITDIGITDIGITDIGIT'],
#  ['round', 'trip', 'first', 'class', 'fares', 'new', 'york', 'to', 'miami'],
#  ['list',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'more',
#   'than',
#   'DIGIT',
#   'stops'],
#  ['show',
#   'me',
#   'the',
#   'price',
#   'of',
#   'all',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'washington',
#   'dc'],
#  ['what', 'about', 'a', 'car', 'rental', 'in', 'denver'],
#  ['on',
#   'september',
#   'fourth',
#   'i',
#   "'ll",
#   'be',
#   'traveling',
#   'from',
#   'pittsburgh',
#   'to',
#   'atlanta',
#   'can',
#   'you',
#   'tell',
#   'me',
#   'what',
#   'flight',
#   'would',
#   'be',
#   'the',
#   'cheapest'],
#  ['show', 'me', 'all', 'nationair', 'flights', 'from', 'toronto'],
#  ['list',
#   'the',
#   'flights',
#   'arriving',
#   'in',
#   'atlanta',
#   'from',
#   'baltimore',
#   'before',
#   'noon',
#   'on',
#   'august',
#   'fourth'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'philadelphia',
#   'arriving',
#   'after',
#   'DIGITDIGITDIGITDIGIT'],
#  ['show', 'me', 'the', 'car', 'rentals', 'in', 'baltimore'],
#  ['i',
#   'want',
#   'a',
#   'flight',
#   'from',
#   'montreal',
#   'quebec',
#   'to',
#   'san',
#   'diego',
#   'california',
#   'that',
#   'leaves',
#   'sunday'],
#  ['what', 'is', 'fare', 'code', 'h'],
#  ['find',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'fare',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco'],
#  ['cheapest', 'flight', 'from', 'miami', 'to', 'indianapolis'],
#  ['what', 'flights', 'from', 'philadelphia', 'to', 'atlanta'],
#  ['show', 'flights', 'between', 'boston', 'and', 'denver'],
#  ['list',
#   'all',
#   'flights',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'us',
#   'air'],
#  ['show',
#   'me',
#   'the',
#   'flights',
#   'from',
#   'washington',
#   'dc',
#   'to',
#   'san',
#   'francisco',
#   'with',
#   'a',
#   'stopover',
#   'in',
#   'denver'],
#  ['what', 'does', 'fn', 'under', 'fare', 'code', 'mean'],
#  ['does',
#   'american',
#   'airlines',
#   'fly',
#   'from',
#   'philadelphia',
#   'to',
#   'san',
#   'francisco'],
#  ['okay',
#   'and',
#   'then',
#   'from',
#   'pittsburgh',
#   'i',
#   "'d",
#   'like',
#   'to',
#   'travel',
#   'to',
#   'atlanta',
#   'on',
#   'september',
#   'fourth'],
#  ['sure', 'i', 'want', 'to', 'go', 'from', 'philadelphia', 'to', 'dallas'],
#  ['okay',
#   'i',
#   "'m",
#   'looking',
#   'for',
#   'a',
#   'flight',
#   'from',
#   'tampa',
#   'to',
#   'st.',
#   'louis',
#   'leaving',
#   'before',
#   'DIGITDIGIT',
#   'am',
#   'any',
#   'day'],
#  ['show', 'me', 'the', 'flights', 'from', 'boston', 'to', 'oakland'],
#  ['show',
#   'me',
#   'the',
#   'nonstop',
#   'flights',
#   'from',
#   'dallas',
#   'to',
#   'houston'],
#  ['what',
#   'northwest',
#   'airline',
#   'flights',
#   'leave',
#   'denver',
#   'before',
#   'noon'],
#  ['i', "'d", 'like', 'to', 'fly', 'from', 'boston', 'to', 'san', 'francisco'],
#  ['what',
#   "'s",
#   'the',
#   'lowest',
#   'round',
#   'trip',
#   'fare',
#   'from',
#   'dallas',
#   'to',
#   'atlanta'],
#  ['does',
#   'continental',
#   'airlines',
#   'fly',
#   'from',
#   'denver',
#   'to',
#   'san',
#   'francisco'],
#  ['show',
#   'me',
#   'flights',
#   'from',
#   'milwaukee',
#   'to',
#   'orlando',
#   'on',
#   'wednesday',
#   'night'],
#  ['what',
#   'are',
#   'the',
#   'coach',
#   'fares',
#   'for',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'denver'],
#  ['show', 'flights', 'from', 'pittsburgh', 'into', 'san', 'francisco'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'find',
#   'a',
#   'flight',
#   'from',
#   'charlotte',
#   'north',
#   'carolina',
#   'to',
#   'las',
#   'vegas',
#   'i',
#   'would',
#   'like',
#   'a',
#   'stopover',
#   'in',
#   'st.',
#   'louis'],
#  ['united', 'airlines', 'flights', 'stopping', 'in', 'denver'],
#  ['what', 'flights', 'are', 'there', 'between', 'atlanta', 'and', 'denver'],
#  ['how',
#   'many',
#   'flights',
#   'does',
#   'eastern',
#   'airlines',
#   'have',
#   'from',
#   'boston',
#   'to',
#   'atlanta'],
#  ['list',
#   'the',
#   'cheapest',
#   'one',
#   'way',
#   'flight',
#   'from',
#   'miami',
#   'florida',
#   'to',
#   'charlotte',
#   'north',
#   'carolina'],
#  ['what',
#   'are',
#   'the',
#   'cheapest',
#   'round',
#   'trip',
#   'flights',
#   'from',
#   'denver',
#   'to',
#   'atlanta'],
#  ['show', 'me', 'the', 'flights', 'from', 'boston', 'to', 'oakland'],
#  ['find', 'a', 'flight', 'from', 'boston', 'to', 'washington', 'on', 'monday'],
#  ['are',
#   'there',
#   'any',
#   'nonstop',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'san',
#   'diego',
#   'on',
#   'wednesday',
#   'may',
#   'twelfth'],
#  ['what',
#   'flights',
#   'are',
#   'available',
#   'from',
#   'pittsburgh',
#   'to',
#   'boston',
#   'on',
#   'wednesday',
#   'of',
#   'next',
#   'week'],
#  ['list',
#   'the',
#   'flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'thursday'],
#  ['please',
#   'list',
#   'nonstop',
#   'twa',
#   'flights',
#   'from',
#   'las',
#   'vegas',
#   'to',
#   'new',
#   'york'],
#  ['show',
#   'all',
#   'flights',
#   'on',
#   'lufthansa',
#   'airlines',
#   'out',
#   'of',
#   'boston'],
#  ['show', 'me', 'about', 'the', 'ground', 'transportation', 'in', 'boston'],
#  ['show', 'me', 'the', 'flights', 'from', 'boston', 'to', 'dallas'],
#  ['what',
#   'transportation',
#   'is',
#   'available',
#   'from',
#   'the',
#   'dallas',
#   'airport',
#   'to',
#   'downtown'],
#  ['please',
#   'list',
#   'the',
#   'flight',
#   'times',
#   'from',
#   'pittsburgh',
#   'to',
#   'newark'],
#  ['show',
#   'me',
#   'round',
#   'trip',
#   'first',
#   'class',
#   'tickets',
#   'from',
#   'new',
#   'york',
#   'to',
#   'miami'],
#  ['are',
#   'they',
#   'all',
#   'nonstop',
#   'flights',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'st.',
#   'paul'],
#  ['flights', 'from', 'kansas', 'city', 'to', 'cleveland', 'on', 'wednesday'],
#  ['what', 'does', 'fare', 'code', 'qo', 'mean'],
#  ['i',
#   'am',
#   'interested',
#   'in',
#   'booking',
#   'an',
#   'early',
#   'morning',
#   'flight',
#   'from',
#   'dallas',
#   'into',
#   'houston',
#   'and',
#   'returning',
#   'in',
#   'the',
#   'late',
#   'evening'],
#  ['list',
#   'all',
#   '<UNK>',
#   '<UNK>',
#   'airline',
#   'flights',
#   'from',
#   'indianapolis',
#   'to',
#   'houston',
#   'that',
#   'arrive',
#   'in',
#   'houston',
#   'between',
#   'DIGITDIGITDIGITDIGIT',
#   'am',
#   'and',
#   'DIGITDIGITDIGITDIGIT',
#   'am'],
#  ['list',
#   'flights',
#   'from',
#   'atlanta',
#   'to',
#   'boston',
#   'on',
#   'wednesday',
#   'afternoon'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'see',
#   'all',
#   'the',
#   'economy',
#   'fares',
#   'from',
#   'baltimore',
#   'to',
#   'philadelphia'],
#  ['i',
#   'need',
#   'a',
#   'reservation',
#   'from',
#   'baltimore',
#   'to',
#   'san',
#   'francisco'],
#  ['show',
#   'me',
#   'us',
#   'air',
#   'flights',
#   'from',
#   'san',
#   'francisco',
#   'to',
#   'pittsburgh',
#   'on',
#   'tuesday'],
#  ['i',
#   "'d",
#   'like',
#   'the',
#   'cheapest',
#   'cost',
#   'fare',
#   'to',
#   'fort',
#   'worth',
#   'from',
#   'boston'],
#  ['what',
#   'is',
#   'the',
#   'earliest',
#   'flight',
#   'from',
#   'tampa',
#   'to',
#   'milwaukee',
#   'tomorrow'],
#  ['how',
#   'much',
#   'is',
#   'the',
#   'cheapest',
#   'flight',
#   'from',
#   'denver',
#   'to',
#   'pittsburgh'],
#  ['show', 'me', 'the', 'flights', 'from', 'dallas', 'to', 'san', 'francisco'],
#  ['tell',
#   'me',
#   'about',
#   'flights',
#   'leaving',
#   'from',
#   'atlanta',
#   'and',
#   'going',
#   'to',
#   'charlotte',
#   'north',
#   'carolina',
#   'next',
#   'monday',
#   'i',
#   'need',
#   'to',
#   'know',
#   'about',
#   'flights',
#   'that',
#   'arrive',
#   'in',
#   'charlotte',
#   'between',
#   'DIGITDIGITDIGIT',
#   'and',
#   'DIGITDIGITDIGIT',
#   'pm'],
#  ['i',
#   'am',
#   'interested',
#   'in',
#   'booking',
#   'an',
#   'early',
#   'morning',
#   'flight',
#   'from',
#   'dallas',
#   'into',
#   'houston',
#   'on',
#   'february',
#   'twenty',
#   'second',
#   'and',
#   'returning',
#   'late',
#   'in',
#   'the',
#   'evening',
#   'of',
#   'february',
#   'twenty',
#   'second'],
#  ['i',
#   'want',
#   'to',
#   'travel',
#   'from',
#   'kansas',
#   'city',
#   'to',
#   'chicago',
#   'round',
#   'trip',
#   'leaving',
#   'wednesday',
#   'june',
#   'sixteenth',
#   'arriving',
#   'in',
#   'chicago',
#   'at',
#   'around',
#   'DIGIT',
#   "o'clock",
#   'in',
#   'the',
#   'evening',
#   'and',
#   'returning',
#   'the',
#   'next',
#   'day',
#   'arriving',
#   'in',
#   'kansas',
#   'city',
#   'at',
#   'around',
#   'DIGIT',
#   "o'clock",
#   'in',
#   'the',
#   'evening',
#   'which',
#   'airlines',
#   'fly',
#   'that',
#   '<UNK>'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'to',
#   'dallas',
#   'from',
#   'san',
#   'francisco',
#   'atlanta',
#   'and',
#   'pittsburgh'],
#  ['flight', 'information', 'from', 'pittsburgh', 'to', 'denver'],
#  ['how', 'far', 'is', 'the', 'airport', 'from', 'downtown', 'pittsburgh'],
#  ['flights',
#   'from',
#   'pittsburgh',
#   'to',
#   'baltimore',
#   'arriving',
#   'between',
#   'DIGIT',
#   'and',
#   'DIGIT',
#   'pm'],
#  ['show',
#   'me',
#   'all',
#   'flights',
#   'from',
#   'philadelphia',
#   'to',
#   'dallas',
#   'which',
#   'arrive',
#   'in',
#   'dallas',
#   'before',
#   'DIGIT',
#   "o'clock",
#   'pm',
#   'on',
#   'saturday'],
#  ['can',
#   'you',
#   'list',
#   'all',
#   'flights',
#   'from',
#   'toronto',
#   'to',
#   'san',
#   'diego'],
#  ['what',
#   'is',
#   'the',
#   'first',
#   'flight',
#   'after',
#   'DIGITDIGIT',
#   'noon',
#   'from',
#   'washington',
#   'for',
#   'denver'],
#  ['i',
#   "'d",
#   'like',
#   'to',
#   'fly',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'could',
#   'you',
#   'find',
#   'me',
#   'the',
#   'cheapest',
#   'fare'],
#  ['may', 'i', 'fly', 'from', 'san', 'francisco', 'to', 'baltimore'],
#  ['what',
#   'is',
#   'the',
#   'first',
#   'flight',
#   'from',
#   'boston',
#   'to',
#   'san',
#   'francisco',
#   'on',
#   'saturday'],
#  ['i',
#   'would',
#   'like',
#   'an',
#   'early',
#   'morning',
#   'flight',
#   'from',
#   'chicago',
#   'into',
#   'seattle',
#   'on',
#   'continental',
#   'airlines']]

# %% [markdown]
# # How does the data look like?
# In order to represent sentences and to make them machine understandable, data has to be processed. At first a dictionary is built. Within the dictionary each word is associated with an index. Given the dictionary and a sentence, a normal textural sentence is converted an array of indices.

# %%
# The first sentence in the training data set
train_lex[0]
# Out:
# array([554, 194, 268,  64,  62,  16,   8, 234, 481,  20,  40,  58, 234,
#        415, 205], dtype=int32)

# %%
# The first sentence in the training data set
example_sentence = train_lex[0]
print(example_sentence)
# Out:
# [554 194 268  64  62  16   8 234 481  20  40  58 234 415 205]

# %%
print(arraysentence2string(example_sentence))
# Out:
# what flights leave atlanta at about DIGIT in the afternoon and arrive in san francisco

# %%
# The first label in the training data set
example_labels = train_y[0]
print(example_labels)
# Out:
# [126 126 126  48 126  36  35 126 126  33 126 126 126  78 123]

# %%
print(arraylabels2string(example_labels))
# Out:
# O O O B-fromloc.city_name O B-depart_time.time_relative B-depart_time.time O O B-depart_time.period_of_day O O O B-toloc.city_name I-toloc.city_name

# %% [markdown]
# ## Context window
# Words in itself can be ambigious, therefore it is useful to consider them in their context. As an example the word 'Paris' could relate to the actress 'Paris Hilton' or the city of Paris. Therefore each word is normally considered within its context. That is we look what comes before and after the word we are interested. Special cases are the beginning and the end of a sentence. In that case we use padding (-1) to highlight this.

# %%
win_size = 5 
csample = contextwin(example_sentence, win_size)

for x in csample:
        print(x)
        print(arraysentence2string(x)+'\n')
# Out:
# [-1, -1, 554, 194, 268]
# what flights leave
#
# [-1, 554, 194, 268, 64]
# what flights leave atlanta
#
# [554, 194, 268, 64, 62]
# what flights leave atlanta at
#
# [194, 268, 64, 62, 16]
# flights leave atlanta at about
#
# [268, 64, 62, 16, 8]
# leave atlanta at about DIGIT
#
# [64, 62, 16, 8, 234]
# atlanta at about DIGIT in
#
# [62, 16, 8, 234, 481]
# at about DIGIT in the
#
# [16, 8, 234, 481, 20]
# about DIGIT in the afternoon
#
# [8, 234, 481, 20, 40]
# DIGIT in the afternoon and
#
# [234, 481, 20, 40, 58]
# in the afternoon and arrive
#
# [481, 20, 40, 58, 234]
# the afternoon and arrive in
#
# [20, 40, 58, 234, 415]
# afternoon and arrive in san
#
# [40, 58, 234, 415, 205]
# and arrive in san francisco
#
# [58, 234, 415, 205, -1]
# arrive in san francisco
#
# [234, 415, 205, -1, -1]
# in san francisco

# %%
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %%
# Now let's define a RNN
class RNNSLU(object):
    ''' elman neural net model '''
    def __init__(self, nh, nc, ne, de, cs):
        '''
        nh :: dimension of the hidden layer
        nc :: number of classes
        ne :: number of word embeddings in the vocabulary / size of vocabulary
        de :: dimension of the word embeddings
        cs :: word window context size
        '''
        
        # parameters of the model
        self.emb = theano.shared(name='embeddings',
                                 value=0.2 * numpy.random.uniform(-1.0, 1.0,
                                 (ne+1, de))
                                 # add one for padding at the end
                                 .astype(theano.config.floatX))
        self.wx = theano.shared(name='wx',
                                value=0.2 * numpy.random.uniform(-1.0, 1.0,
                                (de * cs, nh))
                                .astype(theano.config.floatX))
        self.wh = theano.shared(name='wh',
                                value=0.2 * numpy.random.uniform(-1.0, 1.0,
                                (nh, nh))
                                .astype(theano.config.floatX))
        self.w = theano.shared(name='w',
                               value=0.2 * numpy.random.uniform(-1.0, 1.0,
                               (nh, nc))
                               .astype(theano.config.floatX))
        self.bh = theano.shared(name='bh',
                                value=numpy.zeros(nh,
                                dtype=theano.config.floatX))
        self.b = theano.shared(name='b',
                               value=numpy.zeros(nc,
                               dtype=theano.config.floatX))
        self.h0 = theano.shared(name='h0',
                                value=numpy.zeros(nh,
                                dtype=theano.config.floatX))
        
        

        # bundle the parameters together, nice for gradient computation
        self.params = [self.emb, self.wx, self.wh, self.w,
                       self.bh, self.b, self.h0]
        
        # we perform training on a complete sentence, which is broken down into context window elements
        
        # input is a matrix full of indices:
        # as many columns as context window size
        # as many lines as words in the sentence (each word is presented within context window)
        idxs = T.imatrix()
        
        # map the input to the embedding space
        x = self.emb[idxs].reshape((idxs.shape[0], de*cs))
        
        # labels for the words in the stenence
        y_sentence = T.ivector('y_sentence')
        
        
        # basic Elmann recurrent networks
        
        def recurrence(x_t, h_tm1):
            
            # hidden state
            h_t = T.nnet.sigmoid(T.dot(x_t, self.wx)
                                 + T.dot(h_tm1, self.wh) + self.bh)
            
            # output
            s_t = T.nnet.softmax(T.dot(h_t, self.w) + self.b)
            
            return [h_t, s_t]

        # looping over the words in the sentence
        [h, s], _ = theano.scan(fn=recurrence, #first argument is the time sliced input
                                # input
                                sequences=x,
                                # initial value, must have the same dimension as output [h_t, s_t]
                                outputs_info=[self.h0, None],
                                # number of steps in the loop (corresponds to words in the sentence)
                                n_steps=x.shape[0])

        # output of the RNN is softmax result (probabilities)
        p_y_given_x_sentence = s[:, 0, :]
        
        # for each word return the class with maximum probability
        y_pred = T.argmax(p_y_given_x_sentence, axis=1)
        

        # cost and gradients and learning rate
        lr = T.scalar('lr')

        # cost function is the negative log-likelihood (NLL)
        
        
        # x.shape[0] is (symbolically) the number of rows in x, i.e.,
        # number of words in the sentence (call it n) in the minibatch
        # T.arange(x.shape[0]) is a symbolic vector which will contain
        # [0,1,2,... n-1] T.log(self.p_y_given_x_sentence) is a matrix of
        # Log-Probabilities (call it LP) with one row per word and
        # one column per class LP[T.arange(x.shape[0]),y_sentence] is a vector
        # v containing [LP[0,y_sentence[0]], LP[1,y_sentence[1]], LP[2,y_sentence[2]], ...,
        # LP[n-1,y_sentence[n-1]]] and T.mean(LP[T.arange(x.shape[0]),y_sentence]) is
        # the mean (across minibatch examples) of the elements in v,
        # i.e., the mean log-likelihood across the minibatch.
        
        sentence_nll = -T.mean(T.log(p_y_given_x_sentence)
                               [T.arange(x.shape[0]), y_sentence])
        
        # now let theano do the ugly work and compute the SYMBOLIC gradients
        sentence_gradients = T.grad(sentence_nll, self.params)
        
        # the updates is an ordered dicitionary, where each pair is a parameter and how it is updated (gradient descent)
        sentence_updates = OrderedDict((p, p - lr*g)
                                       for p, g in
                                       zip(self.params, sentence_gradients))
    

        # theano functions to compile
        
        # classification function: 
        # INPUT: sentence (put in context windows)
        # RETURN: vector (class for each word)
        self.classify = theano.function(inputs=[idxs], outputs=y_pred)
        
        # training function:
        # INPUT: sentence (put in context windows), class labels for each word (vector), and a learning rate
        # RETURN: cost (negative log likelihood)
        self.sentence_train = theano.function(inputs=[idxs, y_sentence, lr],
                                              outputs=sentence_nll, 
                                              updates=sentence_updates)
        
        # normalization function (normalization of the embedding)
        # update the embedding, such that it stays on the unit-ball (L2 norm equal to 1)
        # dimshuffle(0, 'x') ->  make a column out of a 1d vector (N to Nx1)
        self.normalize = theano.function(inputs=[],
                                         updates={self.emb:
                                                  self.emb /
                                                  T.sqrt((self.emb**2)
                                                  .sum(axis=1))
                                                  .dimshuffle(0, 'x')})


    def train(self, x, y, window_size, learning_rate):

        cwords = contextwin(x, window_size)
        #words = map(lambda x: numpy.asarray(x).astype('int32'), cwords)
        words = cwords
        labels = y
        
        #print(words,flush=True)

        self.sentence_train(words, labels, learning_rate)
        self.normalize()

    def save(self, folder):
        for param in self.params:
            numpy.save(os.path.join(folder,
                       param.name + '.npy'), param.get_value())

    def load(self, folder):
        for param in self.params:
            param.set_value(numpy.load(os.path.join(folder,
                            param.name + '.npy')))

# %%
# RNN (training) parameters

# %%
param = {
    'fold': 3,
    # 5 folds 0,1,2,3,4
    'data': 'atis',
    'lr': 0.0970806646812754,
    'verbose': 1,
    'decay': True,
    # decay on the learning rate if improvement stops
    'win': 5,
    # number of words in the context window
    'nhidden': 50,
    # number of hidden units
    'seed': 345,
    'emb_dimension': 3,
    # dimension of word embedding
    'nepochs': 30,
    # 60 is recommended
    'savemodel': False}
print(param)
# Out:
# {'emb_dimension': 3, 'win': 5, 'data': 'atis', 'fold': 3, 'nepochs': 30, 'nhidden': 50, 'savemodel': False, 'verbose': 1, 'seed': 345, 'decay': True, 'lr': 0.0970806646812754}

# %%
folder_name = "RNN"
folder = os.path.join(PREFIX, folder_name)
if not os.path.exists(folder):
    os.mkdir(folder)



# instanciate the model
numpy.random.seed(param['seed'])
random.seed(param['seed'])

rnn = RNNSLU(nh=param['nhidden'],
             nc=nclasses,
             ne=vocsize,
             de=param['emb_dimension'],
             cs=param['win'])

# train with early stopping on validation set
best_f1 = -numpy.inf
param['clr'] = param['lr']
for e in range(param['nepochs']):

    # shuffle
    shuffle([train_lex, train_ne, train_y], param['seed'])

    param['ce'] = e
    tic = timeit.default_timer()

    # for each sentence in the training compute gradient and update
    for i, (x, y) in enumerate(zip(train_lex, train_y)):
        rnn.train(x, y, param['win'], param['clr'])
        #print ('[learning] epoch '+str(e)+' >> '+str(float("{0:.2f}".format((i+1)* 100. / nsentences))))
        #print ('completed in %.2f (sec) <<\r' % (timeit.default_timer() - tic), file=sys.stdout, flush=True)
       

    # evaluation // back into the real world : idx -> words
    predictions_test = [map(lambda x: idx2label[x],
                        rnn.classify(numpy.asarray(
                        contextwin(x, param['win'])).astype('int32')))
                        for x in test_lex]
    predictions_valid = [map(lambda x: idx2label[x],
                         rnn.classify(numpy.asarray(
                         contextwin(x, param['win'])).astype('int32')))
                         for x in valid_lex]

    # evaluation // compute the accuracy using conlleval.pl
    res_test = conlleval(predictions_test,
                         groundtruth_test,
                         words_test,
                         folder + '/current.test.txt')
    res_valid = conlleval(predictions_valid,
                          groundtruth_valid,
                          words_valid,
                          folder + '/current.valid.txt')

    if res_valid['f1'] > best_f1:

        if param['savemodel']:
            rnn.save(folder)

        best_rnn = copy.deepcopy(rnn)
        best_f1 = res_valid['f1']

        if param['verbose']:
            print('NEW BEST: epoch', e,
                  'valid F1', res_valid['f1'],
                  'best test F1', res_test['f1'], flush=True)

        param['vf1'], param['tf1'] = res_valid['f1'], res_test['f1']
        param['vp'], param['tp'] = res_valid['p'], res_test['p']
        param['vr'], param['tr'] = res_valid['r'], res_test['r']
        param['be'] = e

        subprocess.call(['mv', folder + '/current.test.txt',
                        folder + '/best.test.txt'])
        subprocess.call(['mv', folder + '/current.valid.txt',
                        folder + '/best.valid.txt'])
    else:
        if param['verbose']:
            print('')

    # learning rate decay if no improvement in 10 epochs
    if param['decay'] and abs(param['be']-param['ce']) >= 10:
        param['clr'] *= 0.5
        rnn = best_rnn

    if param['clr'] < 1e-5:
        break

print('BEST RESULT: epoch', param['be'],
      'valid F1', param['vf1'],
      'best test F1', param['tf1'],
      'with the model', folder)
# Out:
# NEW BEST: epoch 0 valid F1 52.89 best test F1 47.69
# NEW BEST: epoch 1 valid F1 59.61 best test F1 55.28
# NEW BEST: epoch 2 valid F1 66.59 best test F1 64.78
# NEW BEST: epoch 3 valid F1 72.83 best test F1 71.87
# NEW BEST: epoch 4 valid F1 75.66 best test F1 74.15
# NEW BEST: epoch 5 valid F1 77.57 best test F1 75.58
# NEW BEST: epoch 6 valid F1 79.47 best test F1 77.34
# NEW BEST: epoch 7 valid F1 81.03 best test F1 78.19
# NEW BEST: epoch 8 valid F1 81.68 best test F1 78.99
# NEW BEST: epoch 9 valid F1 81.88 best test F1 80.74
# NEW BEST: epoch 10 valid F1 83.1 best test F1 80.83
# NEW BEST: epoch 11 valid F1 83.45 best test F1 80.76
# NEW BEST: epoch 12 valid F1 84.33 best test F1 82.4
# NEW BEST: epoch 13 valid F1 84.79 best test F1 82.87
# NEW BEST: epoch 14 valid F1 85.82 best test F1 83.43
# NEW BEST: epoch 15 valid F1 86.22 best test F1 83.84
#
# NEW BEST: epoch 17 valid F1 87.05 best test F1 84.99
# NEW BEST: epoch 18 valid F1 87.8 best test F1 85.77
#
#
# NEW BEST: epoch 21 valid F1 87.85 best test F1 86.22
# NEW BEST: epoch 22 valid F1 88.99 best test F1 87.3
#
#
#
# NEW BEST: epoch 26 valid F1 89.36 best test F1 87.41
# NEW BEST: epoch 27 valid F1 89.68 best test F1 87.15
# NEW BEST: epoch 28 valid F1 89.89 best test F1 87.54
#
# BEST RESULT: epoch 28 valid F1 89.89 best test F1 87.54 with the model /home/i311008/RNN
# /usr/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   return f(*args, **kwds)

# %% [markdown]
# ### Now we have a look at the embedding of the words in the vector space

# %%
print(rnn.emb.eval().shape)
# make sure the row-wise norm is equal to 1
assert(np.sum(np.apply_along_axis(np.linalg.norm, 1, rnn.emb.eval())) == rnn.emb.eval().shape[0]),"Embedding not properly normalized: Each row has to have norm 1."
# Out:
# (573, 3)

# %% [markdown]
# ### Now we compute check the nearest neighbors for all elements for sanity check

# %%
nbrs = NearestNeighbors(n_neighbors=10, algorithm='ball_tree').fit(rnn.emb.eval())
distances, indices = nbrs.kneighbors(rnn.emb.eval())

# %%
# What are the different label categories?
idx2word
# Out:
# {0: "'d",
#  1: "'ll",
#  2: "'m",
#  3: "'re",
#  4: "'s",
#  5: "'t",
#  6: '72s',
#  7: '<UNK>',
#  8: 'DIGIT',
#  9: 'DIGITDIGIT',
#  10: 'DIGITDIGITDIGIT',
#  11: 'DIGITDIGITDIGITDIGIT',
#  12: 'DIGITDIGITDIGITDIGITDIGITDIGIT',
#  13: 'a',
#  14: 'abbreviation',
#  15: 'abbreviations',
#  16: 'about',
#  17: 'ac',
#  18: 'actually',
#  19: 'after',
#  20: 'afternoon',
#  21: 'again',
#  22: 'air',
#  23: 'aircraft',
#  24: 'airfare',
#  25: 'airline',
#  26: 'airlines',
#  27: 'airplane',
#  28: 'airplanes',
#  29: 'airport',
#  30: 'airports',
#  31: 'alaska',
#  32: 'all',
#  33: 'along',
#  34: 'also',
#  35: 'am',
#  36: 'america',
#  37: 'american',
#  38: 'amount',
#  39: 'an',
#  40: 'and',
#  41: 'angeles',
#  42: 'another',
#  43: 'any',
#  44: 'anywhere',
#  45: 'ap',
#  46: 'ap57',
#  47: 'ap80',
#  48: 'approximately',
#  49: 'april',
#  50: 'are',
#  51: 'area',
#  52: 'arizona',
#  53: 'around',
#  54: 'arrange',
#  55: 'arrangements',
#  56: 'arrival',
#  57: 'arrivals',
#  58: 'arrive',
#  59: 'arrives',
#  60: 'arriving',
#  61: 'as',
#  62: 'at',
#  63: 'atl',
#  64: 'atlanta',
#  65: 'august',
#  66: 'available',
#  67: 'b',
#  68: 'back',
#  69: 'baltimore',
#  70: 'be',
#  71: 'beach',
#  72: 'before',
#  73: 'between',
#  74: 'boeing',
#  75: 'book',
#  76: 'booking',
#  77: 'boston',
#  78: 'both',
#  79: 'bound',
#  80: 'breakfast',
#  81: 'burbank',
#  82: 'business',
#  83: 'but',
#  84: 'buy',
#  85: 'bwi',
#  86: 'by',
#  87: 'c',
#  88: 'california',
#  89: 'can',
#  90: 'canada',
#  91: 'canadian',
#  92: 'capacity',
#  93: 'car',
#  94: 'carolina',
#  95: 'carries',
#  96: 'cars',
#  97: 'charlotte',
#  98: 'cheap',
#  99: 'cheapest',
#  100: 'chicago',
#  101: 'choices',
#  102: 'cincinnati',
#  103: 'cities',
#  104: 'city',
#  105: 'class',
#  106: 'classes',
#  107: 'cleveland',
#  108: 'close',
#  109: 'co',
#  110: 'coach',
#  111: 'code',
#  112: 'codes',
#  113: 'colorado',
#  114: 'columbus',
#  115: 'coming',
#  116: 'connect',
#  117: 'connecting',
#  118: 'connection',
#  119: 'connections',
#  120: 'continental',
#  121: 'cost',
#  122: 'costs',
#  123: 'could',
#  124: 'county',
#  125: 'cp',
#  126: 'd',
#  127: 'daily',
#  128: 'dallas',
#  129: 'database',
#  130: 'day',
#  131: 'days',
#  132: 'dc',
#  133: 'dc10',
#  134: 'december',
#  135: 'define',
#  136: 'delta',
#  137: 'denver',
#  138: 'depart',
#  139: 'departing',
#  140: 'departs',
#  141: 'departure',
#  142: 'departures',
#  143: 'describe',
#  144: 'destination',
#  145: 'detroit',
#  146: 'dfw',
#  147: 'diego',
#  148: 'difference',
#  149: 'different',
#  150: 'dinner',
#  151: 'dinnertime',
#  152: 'direct',
#  153: 'display',
#  154: 'distance',
#  155: 'dl',
#  156: 'do',
#  157: 'does',
#  158: 'dollars',
#  159: 'downtown',
#  160: 'dulles',
#  161: 'during',
#  162: 'ea',
#  163: 'each',
#  164: 'earlier',
#  165: 'earliest',
#  166: 'early',
#  167: 'eastern',
#  168: 'economy',
#  169: 'eight',
#  170: 'eighteenth',
#  171: 'eighth',
#  172: 'either',
#  173: 'eleventh',
#  174: 'evening',
#  175: 'ewr',
#  176: 'expensive',
#  177: 'explain',
#  178: 'express',
#  179: 'f',
#  180: 'f28',
#  181: 'far',
#  182: 'fare',
#  183: 'fares',
#  184: 'february',
#  185: 'ff',
#  186: 'field',
#  187: 'fifteenth',
#  188: 'fifth',
#  189: 'find',
#  190: 'first',
#  191: 'fit',
#  192: 'flies',
#  193: 'flight',
#  194: 'flights',
#  195: 'florida',
#  196: 'fly',
#  197: 'flying',
#  198: 'fn',
#  199: 'following',
#  200: 'for',
#  201: 'fort',
#  202: 'four',
#  203: 'fourteenth',
#  204: 'fourth',
#  205: 'francisco',
#  206: 'friday',
#  207: 'friends',
#  208: 'from',
#  209: 'general',
#  210: 'georgia',
#  211: 'get',
#  212: 'give',
#  213: 'go',
#  214: 'goes',
#  215: 'going',
#  216: 'great',
#  217: 'ground',
#  218: 'guardia',
#  219: 'h',
#  220: 'has',
#  221: 'have',
#  222: 'heading',
#  223: 'hello',
#  224: 'help',
#  225: 'here',
#  226: 'hi',
#  227: 'highest',
#  228: 'hours',
#  229: 'houston',
#  230: 'how',
#  231: 'hp',
#  232: 'i',
#  233: 'if',
#  234: 'in',
#  235: 'include',
#  236: 'indianapolis',
#  237: 'information',
#  238: 'interested',
#  239: 'international',
#  240: 'into',
#  241: 'is',
#  242: 'it',
#  243: 'itinerary',
#  244: 'january',
#  245: 'jersey',
#  246: 'jfk',
#  247: 'jose',
#  248: 'july',
#  249: 'june',
#  250: 'just',
#  251: 'kansas',
#  252: 'kind',
#  253: 'kinds',
#  254: 'know',
#  255: 'la',
#  256: 'lake',
#  257: 'land',
#  258: 'landing',
#  259: 'landings',
#  260: 'las',
#  261: 'last',
#  262: 'lastest',
#  263: 'late',
#  264: 'later',
#  265: 'latest',
#  266: 'layover',
#  267: 'least',
#  268: 'leave',
#  269: 'leaves',
#  270: 'leaving',
#  271: 'less',
#  272: 'let',
#  273: 'like',
#  274: 'limo',
#  275: 'limousine',
#  276: 'list',
#  277: 'listing',
#  278: 'live',
#  279: 'lives',
#  280: 'located',
#  281: 'logan',
#  282: 'long',
#  283: 'look',
#  284: 'looking',
#  285: 'los',
#  286: 'louis',
#  287: 'love',
#  288: 'lowest',
#  289: 'lufthansa',
#  290: 'lunch',
#  291: 'm',
#  292: 'm80',
#  293: 'make',
#  294: 'makes',
#  295: 'making',
#  296: 'many',
#  297: 'march',
#  298: 'maximum',
#  299: 'may',
#  300: 'mco',
#  301: 'me',
#  302: 'meal',
#  303: 'meals',
#  304: 'mean',
#  305: 'meaning',
#  306: 'memphis',
#  307: 'miami',
#  308: 'michigan',
#  309: 'midnight',
#  310: 'midway',
#  311: 'midwest',
#  312: 'milwaukee',
#  313: 'minneapolis',
#  314: 'minnesota',
#  315: 'missouri',
#  316: 'mitchell',
#  317: 'monday',
#  318: 'month',
#  319: 'montreal',
#  320: 'more',
#  321: 'morning',
#  322: 'mornings',
#  323: 'most',
#  324: 'much',
#  325: 'my',
#  326: 'name',
#  327: 'names',
#  328: 'nashville',
#  329: 'nationair',
#  330: 'near',
#  331: 'need',
#  332: 'new',
#  333: 'newark',
#  334: 'next',
#  335: 'night',
#  336: 'nineteenth',
#  337: 'ninth',
#  338: 'no',
#  339: 'nonstop',
#  340: 'nonstops',
#  341: 'noon',
#  342: 'noontime',
#  343: 'north',
#  344: 'northwest',
#  345: 'november',
#  346: 'now',
#  347: 'number',
#  348: 'numbers',
#  349: 'nw',
#  350: "o'clock",
#  351: 'oakland',
#  352: 'october',
#  353: 'of',
#  354: 'offer',
#  355: 'offers',
#  356: 'ohio',
#  357: 'okay',
#  358: 'on',
#  359: 'one',
#  360: 'only',
#  361: 'ontario',
#  362: 'options',
#  363: 'or',
#  364: 'ord',
#  365: 'originate',
#  366: 'originating',
#  367: 'orlando',
#  368: 'other',
#  369: 'out',
#  370: 'over',
#  371: 'passengers',
#  372: 'paul',
#  373: 'pennsylvania',
#  374: 'people',
#  375: 'petersburg',
#  376: 'philadelphia',
#  377: 'philly',
#  378: 'phoenix',
#  379: 'pittsburgh',
#  380: 'plan',
#  381: 'plane',
#  382: 'planes',
#  383: 'please',
#  384: 'pm',
#  385: 'possible',
#  386: 'price',
#  387: 'prices',
#  388: 'provide',
#  389: 'provided',
#  390: 'q',
#  391: 'qo',
#  392: 'quebec',
#  393: 'qw',
#  394: 'qx',
#  395: 'rate',
#  396: 'rates',
#  397: 'reaching',
#  398: 'rent',
#  399: 'rental',
#  400: 'rentals',
#  401: 'repeat',
#  402: 'requesting',
#  403: 'reservation',
#  404: 'reservations',
#  405: 'restriction',
#  406: 'restrictions',
#  407: 'return',
#  408: 'returning',
#  409: 'right',
#  410: 'round',
#  411: 's',
#  412: 'sa',
#  413: 'salt',
#  414: 'same',
#  415: 'san',
#  416: 'saturday',
#  417: 'saturdays',
#  418: 'say',
#  419: 'schedule',
#  420: 'schedules',
#  421: 'seating',
#  422: 'seats',
#  423: 'seattle',
#  424: 'second',
#  425: 'see',
#  426: 'september',
#  427: 'serve',
#  428: 'served',
#  429: 'serves',
#  430: 'service',
#  431: 'serviced',
#  432: 'services',
#  433: 'serving',
#  434: 'seventeenth',
#  435: 'seventh',
#  436: 'sfo',
#  437: 'shortest',
#  438: 'should',
#  439: 'show',
#  440: 'six',
#  441: 'sixteen',
#  442: 'sixteenth',
#  443: 'sixth',
#  444: 'smallest',
#  445: 'snack',
#  446: 'so',
#  447: 'some',
#  448: 'sometime',
#  449: 'soon',
#  450: 'sorry',
#  451: 'southwest',
#  452: 'st.',
#  453: 'stand',
#  454: 'stands',
#  455: 'stapleton',
#  456: 'starting',
#  457: 'still',
#  458: 'stop',
#  459: 'stopover',
#  460: 'stopovers',
#  461: 'stopping',
#  462: 'stops',
#  463: 'sunday',
#  464: 'sundays',
#  465: 'sure',
#  466: 'tacoma',
#  467: 'take',
#  468: 'takeoff',
#  469: 'takeoffs',
#  470: 'taking',
#  471: 'tampa',
#  472: 'taxi',
#  473: 'tell',
#  474: 'ten',
#  475: 'tennessee',
#  476: 'tenth',
#  477: 'texas',
#  478: 'than',
#  479: 'thank',
#  480: 'that',
#  481: 'the',
#  482: 'their',
#  483: 'then',
#  484: 'there',
#  485: 'these',
#  486: 'they',
#  487: 'third',
#  488: 'thirteenth',
#  489: 'thirtieth',
#  490: 'thirty',
#  491: 'this',
#  492: 'those',
#  493: 'three',
#  494: 'thrift',
#  495: 'through',
#  496: 'thursday',
#  497: 'thursdays',
#  498: 'ticket',
#  499: 'tickets',
#  500: 'time',
#  501: 'times',
#  502: 'to',
#  503: 'today',
#  504: 'tomorrow',
#  505: 'too',
#  506: 'toronto',
#  507: 'total',
#  508: 'tower',
#  509: 'train',
#  510: 'transcontinental',
#  511: 'transport',
#  512: 'transportation',
#  513: 'travel',
#  514: 'traveling',
#  515: 'trip',
#  516: 'trips',
#  517: 'trying',
#  518: 'tuesday',
#  519: 'tuesdays',
#  520: 'turboprop',
#  521: 'twa',
#  522: 'twelfth',
#  523: 'twentieth',
#  524: 'twenty',
#  525: 'two',
#  526: 'type',
#  527: 'types',
#  528: 'ua',
#  529: 'under',
#  530: 'united',
#  531: 'up',
#  532: 'us',
#  533: 'use',
#  534: 'used',
#  535: 'uses',
#  536: 'using',
#  537: 'utah',
#  538: 'various',
#  539: 'vegas',
#  540: 'very',
#  541: 'via',
#  542: 'want',
#  543: 'washington',
#  544: 'way',
#  545: 'we',
#  546: 'wednesday',
#  547: 'wednesdays',
#  548: 'week',
#  549: 'weekday',
#  550: 'weekdays',
#  551: 'well',
#  552: 'west',
#  553: 'westchester',
#  554: 'what',
#  555: 'when',
#  556: 'where',
#  557: 'which',
#  558: 'who',
#  559: 'will',
#  560: 'wish',
#  561: 'with',
#  562: 'within',
#  563: 'without',
#  564: 'worth',
#  565: 'would',
#  566: 'y',
#  567: 'yes',
#  568: 'yn',
#  569: 'york',
#  570: 'you',
#  571: 'your'}

# %%
# show the nearest neighbor to the word 'philadelphia'
idx = 376
[idx2word[x] for x in indices[idx]]
# Out:
# ['philadelphia',
#  'baltimore',
#  'chicago',
#  'oakland',
#  'boston',
#  'pittsburgh',
#  'cincinnati',
#  'memphis',
#  'miami',
#  'eighth']

# %%
# show the nearest neighbor to the word 'saturday'
idx = 420
[idx2word[x] for x in indices[idx]]
# Out:
# ['schedules',
#  'arizona',
#  'train',
#  'taxi',
#  'time',
#  'highest',
#  'schedule',
#  'under',
#  'times',
#  'economy']

# %%
# show the nearest neighbor to the word 'august'
idx = 65
[idx2word[x] for x in indices[idx]]
# Out:
# ['august',
#  'june',
#  'november',
#  'july',
#  'ap',
#  'september',
#  'december',
#  'april',
#  'january',
#  'rental']

# %%
# show the nearest neighbor to the word 'breakfast'
idx = 80
[idx2word[x] for x in indices[idx]]
# Out:
# ['breakfast',
#  'dinner',
#  'sixteen',
#  'florida',
#  'california',
#  'qw',
#  'carolina',
#  'f',
#  'thirteenth',
#  'expensive']
